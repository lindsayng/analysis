# %% [markdown]
# # Imports and Functions

# %%
import pg8000
import pandas as pd    
import os, re
import numpy as np
import matplotlib.pyplot as plt
from allensdk.core.nwb_data_set import NwbDataSet
import allensdk.ephys.ephys_features as aef
import allensdk.ephys.extract_cell_features as ecf
import seaborn as sns
#from research_ops_tools.lims2_funcs import get_lims_dataframe
#from allensdk.internal.core.lims_utilities import linux_to_windows

import warnings
warnings.filterwarnings('ignore')

sns.set()

# %%
#code from Agata
#these are nice functions to open LIMS, make a query and then close LIMS after

def _connect(user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    conn = pg8000.connect(user=user, host=host, database=database, password=password, port=port)
    return conn, conn.cursor()

def _select(cursor, query):
    cursor.execute(query)
    columns = [ d[0] for d in cursor.description ]
    return [ dict(zip(columns, c)) for c in cursor.fetchall() ]

def limsquery(query, user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    """A function that takes a string containing a SQL query, connects to the LIMS database and outputs the result."""
    conn, cursor = _connect(user, host, database, password, port)
    try:
        results = _select(cursor, query)
    finally:
        
        #THESE ARE IMPORTANT!!!!!!
        #Every query needs to be closed when done
        cursor.close()             
        conn.close()
    return results


#this last function will take our query results and put them in a dataframe so that they are easy to work with
def get_lims_dataframe(query):
    '''Return a dataframe with lims query'''
    result = limsquery(query)
    try:
        data_df = pd.DataFrame(data=result, columns=result[0].keys())
    except IndexError:
        print "Could not find results for your query."
        data_df = pd.DataFrame()
    return data_df

# %% [markdown]
# # Obtain ephys data from LIMS

# %%
q = """
SELECT cell.name,
cell.id,
SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) AS container_date,
ef.*
FROM specimens cell 
JOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id
JOIN projects proj ON cell.project_id = proj.id
LEFT JOIN ephys_features ef on ef.specimen_id = cell.id
WHERE SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) BETWEEN '180101' AND '999999'
AND proj.code in ('hIVSCC-MET', 'hIVSCC-METc')"""

lims_df = get_lims_dataframe(q)
lims_df
# Out:
#             tau  upstroke_downstroke_ratio_short_square  thumbnail_sweep_id  \
# 0           NaN                                     NaN                 NaN
# 1           NaN                                     NaN                 NaN
# 2           NaN                                     NaN                 NaN
# 3     22.641362                                1.777143        1.040521e+09
# 4           NaN                                     NaN                 NaN
# 5           NaN                                     NaN                 NaN
# 6           NaN                                     NaN                 NaN
# 7     12.217778                                1.806691        1.040518e+09
# 8           NaN                                     NaN                 NaN
# 9     18.535130                                2.228835        1.040521e+09
# 10          NaN                                     NaN                 NaN
# 11    11.205049                                2.699902        1.040521e+09
# 12          NaN                                     NaN                 NaN
# 13    31.482299                                2.139806        1.040522e+09
# 14          NaN                                     NaN                 NaN
# 15    36.346401                                0.970841        1.040522e+09
# 16    12.586813                                3.113127        9.973877e+08
# 17          NaN                                     NaN                 NaN
# 18    14.891768                                2.270784        1.040527e+09
# 19          NaN                                     NaN                 NaN
# 20    16.242909                                2.965014        1.040527e+09
# 21          NaN                                     NaN                 NaN
# 22    22.459305                                2.977344        9.973881e+08
# 23          NaN                                     NaN                 NaN
# 24    11.937324                                2.579842        9.973885e+08
# 1960      None               NaN                  NaN
# 1961      None               NaN                  NaN
# 1962      None               NaN                  NaN
# 1963      None               NaN                  NaN
# 1964      None               NaN                  NaN
# 1965      None               NaN                  NaN
# 1966      None               NaN                  NaN
# 1967      None               NaN                  NaN
# 1968      None               NaN                  NaN
# 1969      None               NaN                  NaN
#
#       upstroke_downstroke_ratio_ramp       sag                  updated_at  \
# 0                                NaN       NaN                        None
# 1                                NaN       NaN                        None
# 2                                NaN       NaN                        None
# 3                           2.390769  0.145818  2020-08-17 18:31:42.853652
# 4                                NaN       NaN                        None
# 5                                NaN       NaN                        None
# 6                                NaN       NaN                        None
# 7                                NaN  0.371542  2020-08-17 18:31:30.220258
# 8                                NaN       NaN                        None
# 9                           2.456655  0.396388  2020-08-17 18:29:08.933770
# 10                               NaN       NaN                        None
# 11                          2.684274  0.091086  2020-08-17 18:16:26.411308
# 12                               NaN       NaN                        None
# 13                          2.191726  0.218434  2020-08-17 18:13:28.283937
# 14                               NaN       NaN                        None
# 15                          0.928581  0.106809  2020-08-17 18:13:28.666662
# 16                          3.053565  0.024625  2020-01-02 21:42:49.241241
# 17                               NaN       NaN                        None
# 18                          2.145213  0.230235  2020-08-17 18:11:46.146785
# 19                               NaN       NaN                        None
# 20                          3.591385  0.124175  2020-08-17 18:12:46.543593
# 21                               NaN       NaN                        None
# 22                          3.070429 -0.006325  2020-01-02 21:41:57.130562
# 23                               NaN       NaN                        None
# 24                          2.765911  0.050039  2020-01-02 21:42:43.053670
# 25                          2.594424  0.258902  2020-08-17 18:15:03.057255
# 26                               NaN       NaN                        None
# 27                               NaN       NaN                        None
# 28                               NaN       NaN                        None
# 29                               NaN       NaN                        None
# ...                              ...       ...                         ...
# 1940                             NaN       NaN                        None
# 1941                             NaN       NaN                        None
# 1942                             NaN       NaN                        None
# 1943                             NaN       NaN                        None
# 1944                             NaN       NaN                        None
# 1945                             NaN       NaN                        None
# 1946                             NaN       NaN                        None
# 1947                             NaN       NaN                        None
# 1948                             NaN       NaN                        None
# 1949                             NaN       NaN                        None
# 1950                             NaN       NaN                        None
# 1951                             NaN       NaN                        None
# 1952                             NaN       NaN                        None
# 1953                             NaN       NaN                        None
# 1954                             NaN       NaN                        None
# 1955                             NaN       NaN                        None
# 1956                             NaN       NaN                        None
# 1957                             NaN       NaN                        None
# 1958                             NaN       NaN                        None
# 1959                             NaN       NaN                        None
# 1960                             NaN       NaN                        None
# 1961                             NaN       NaN                        None
# 1962                             NaN       NaN                        None
# 1963                             NaN       NaN                        None
# 1964                             NaN       NaN                        None
# 1965                             NaN       NaN                        None
# 1966                             NaN       NaN                        None
# 1967                             NaN       NaN                        None
# 1968                             NaN       NaN                        None
# 1969                             NaN       NaN                        None
#
#       threshold_t_ramp     ...      trough_v_short_square  f_i_curve_slope  \
# 0                  NaN     ...                        NaN              NaN
# 1                  NaN     ...                        NaN              NaN
# 2                  NaN     ...                        NaN              NaN
# 3             2.721780     ...                 -64.203125         0.198661
# 4                  NaN     ...                        NaN              NaN
# 5                  NaN     ...                        NaN              NaN
# 6                  NaN     ...                        NaN              NaN
# 7                  NaN     ...                 -68.010414         0.353554
# 8                  NaN     ...                        NaN              NaN
# 9             0.959700     ...                 -63.083332         0.041943
# 10                 NaN     ...                        NaN              NaN
# 11            1.949180     ...                 -73.757812         0.237143
# 12                 NaN     ...                        NaN              NaN
# 13            5.751150     ...                 -70.897324         0.114196
# 14                 NaN     ...                        NaN              NaN
# 15            1.739200     ...                 -53.017361         0.240127
# 16           10.024080     ...                 -76.359375         0.113351
# 17                 NaN     ...                        NaN              NaN
# 18            2.508160     ...                 -60.781250         0.373571
# 19                 NaN     ...                        NaN              NaN
# 20            4.089540     ...                 -60.726566         0.228571
# 21                 NaN     ...                        NaN              NaN
# 22            6.229640     ...                 -87.890625         0.143750
# 23                 NaN     ...                        NaN              NaN
# 24            8.999233     ...                 -79.614586         0.108214
# 25            4.858720     ...                 -45.328125         0.402500
# 26                 NaN     ...                        NaN              NaN
# 27                 NaN     ...                        NaN              NaN
# 28                 NaN     ...                        NaN              NaN
# 29                 NaN     ...                        NaN              NaN
# ...                ...     ...                        ...              ...
# 1940               NaN     ...                        NaN              NaN
# 1941               NaN     ...                        NaN              NaN
# 1942               NaN     ...                        NaN              NaN
# 1943               NaN     ...                        NaN              NaN
# 1944               NaN     ...                        NaN              NaN
# 1945               NaN     ...                        NaN              NaN
# 1946               NaN     ...                        NaN              NaN
# 1947               NaN     ...                        NaN              NaN
# 1948               NaN     ...                        NaN              NaN
# 1949               NaN     ...                        NaN              NaN
# 1950               NaN     ...                        NaN              NaN
# 1951               NaN     ...                        NaN              NaN
# 1952               NaN     ...                        NaN              NaN
# 1953               NaN     ...                        NaN              NaN
# 1954               NaN     ...                        NaN              NaN
# 1955               NaN     ...                        NaN              NaN
# 1956               NaN     ...                        NaN              NaN
# 1957               NaN     ...                        NaN              NaN
# 1958               NaN     ...                        NaN              NaN
# 1959               NaN     ...                        NaN              NaN
# 1960               NaN     ...                        NaN              NaN
# 1961               NaN     ...                        NaN              NaN
# 1962               NaN     ...                        NaN              NaN
# 1963               NaN     ...                        NaN              NaN
# 1964               NaN     ...                        NaN              NaN
# 1965               NaN     ...                        NaN              NaN
# 1966               NaN     ...                        NaN              NaN
# 1967               NaN     ...                        NaN              NaN
# 1968               NaN     ...                        NaN              NaN
# 1969               NaN     ...                        NaN              NaN
#
#                       created_at  peak_t_long_square  latency  \
# 0                           None                 NaN      NaN
# 1                           None                 NaN      NaN
# 2                           None                 NaN      NaN
# 3     2020-08-16 00:50:31.473692             0.75468  0.02196
# 4                           None                 NaN      NaN
# 5                           None                 NaN      NaN
# 6                           None                 NaN      NaN
# 7     2020-08-16 00:50:53.256168             0.51856  0.01228
# 8                           None                 NaN      NaN
# 9     2020-08-16 00:55:56.738257             0.66842  0.01632
# 10                          None                 NaN      NaN
# 11    2020-08-16 00:56:59.290154             0.61806  0.01818
# 12                          None                 NaN      NaN
# 13    2020-08-16 00:59:17.901739             0.65660  0.07528
# 14                          None                 NaN      NaN
# 15    2020-08-16 00:59:16.853543             0.51480  0.00808
# 16    2020-01-02 21:42:49.241241             0.74208  0.08844
# 17                          None                 NaN      NaN
# 18    2020-08-16 00:58:50.222996             0.52496  0.01012
# 19                          None                 NaN      NaN
# 20    2020-08-16 00:59:01.837968             0.60982  0.02992
# 21                          None                 NaN      NaN
# 22    2020-01-02 21:41:57.130562             0.78846  0.28780
# 23                          None                 NaN      NaN
# 24    2020-01-02 21:42:43.053670             0.70056  0.08396
# 25    2020-08-16 00:56:25.979681             0.63180  0.01640
# 26                          None                 NaN      NaN
# 27                          None                 NaN      NaN
# 28                          None                 NaN      NaN
# 29                          None                 NaN      NaN
# ...                          ...                 ...      ...
# 1940                        None                 NaN      NaN
# 1941                        None                 NaN      NaN
# 1942                        None                 NaN      NaN
# 1943                        None                 NaN      NaN
# 1944                        None                 NaN      NaN
# 1945                        None                 NaN      NaN
# 1946                        None                 NaN      NaN
# 1947                        None                 NaN      NaN
# 1948                        None                 NaN      NaN
# 1949                        None                 NaN      NaN
# 1950                        None                 NaN      NaN
# 1951                        None                 NaN      NaN
# 1952                        None                 NaN      NaN
# 1953                        None                 NaN      NaN
# 1954                        None                 NaN      NaN
# 1955                        None                 NaN      NaN
# 1956                        None                 NaN      NaN
# 1957                        None                 NaN      NaN
# 1958                        None                 NaN      NaN
# 1959                        None                 NaN      NaN
# 1960                        None                 NaN      NaN
# 1961                        None                 NaN      NaN
# 1962                        None                 NaN      NaN
# 1963                        None                 NaN      NaN
# 1964                        None                 NaN      NaN
# 1965                        None                 NaN      NaN
# 1966                        None                 NaN      NaN
# 1967                        None                 NaN      NaN
# 1968                        None                 NaN      NaN
# 1969                        None                 NaN      NaN
#
#       fast_trough_v_long_square  upstroke_downstroke_ratio_long_square  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                    -44.937504                               2.497027
# 4                           NaN                                    NaN
# 5                           NaN                                    NaN
# 6                           NaN                                    NaN
# 7                    -65.875000                               1.750159
# 8                           NaN                                    NaN
# 9                    -50.937504                               2.349560
# 10                          NaN                                    NaN
# 11                   -67.937500                               2.700423
# 12                          NaN                                    NaN
# 13                   -59.625004                               2.445726
# 14                          NaN                                    NaN
# 15                   -48.906250                               1.411482
# 16                   -48.031250                               3.454538
# 17                          NaN                                    NaN
# 18                   -53.343754                               2.565083
# 19                          NaN                                    NaN
# 20                   -49.093754                               3.306106
# 21                          NaN                                    NaN
# 22                   -62.500000                               3.216786
# 23                          NaN                                    NaN
# 24                   -49.593750                               3.008855
# 25                   -39.625000                               2.543695
# 26                          NaN                                    NaN
# 27                          NaN                                    NaN
# 28                          NaN                                    NaN
# 29                          NaN                                    NaN
# ...                         ...                                    ...
# 1940                        NaN                                    NaN
# 1941                        NaN                                    NaN
# 1942                        NaN                                    NaN
# 1943                        NaN                                    NaN
# 1944                        NaN                                    NaN
# 1945                        NaN                                    NaN
# 1946                        NaN                                    NaN
# 1947                        NaN                                    NaN
# 1948                        NaN                                    NaN
# 1949                        NaN                                    NaN
# 1950                        NaN                                    NaN
# 1951                        NaN                                    NaN
# 1952                        NaN                                    NaN
# 1953                        NaN                                    NaN
# 1954                        NaN                                    NaN
# 1955                        NaN                                    NaN
# 1956                        NaN                                    NaN
# 1957                        NaN                                    NaN
# 1958                        NaN                                    NaN
# 1959                        NaN                                    NaN
# 1960                        NaN                                    NaN
# 1961                        NaN                                    NaN
# 1962                        NaN                                    NaN
# 1963                        NaN                                    NaN
# 1964                        NaN                                    NaN
# 1965                        NaN                                    NaN
# 1966                        NaN                                    NaN
# 1967                        NaN                                    NaN
# 1968                        NaN                                    NaN
# 1969                        NaN                                    NaN
#
#       trough_v_ramp  peak_v_long_square  adaptation
# 0               NaN                 NaN         NaN
# 1               NaN                 NaN         NaN
# 2               NaN                 NaN         NaN
# 3        -46.781254           29.218752   -0.014374
# 4               NaN                 NaN         NaN
# 5               NaN                 NaN         NaN
# 6               NaN                 NaN         NaN
# 7               NaN           27.468752   -0.096957
# 8               NaN                 NaN         NaN
# 9        -56.531250           19.125002    0.034384
# 10              NaN                 NaN         NaN
# 11       -69.812508           37.187500    0.010853
# 12              NaN                 NaN         NaN
# 13       -57.843754           39.718750    0.085137
# 14              NaN                 NaN         NaN
# 15       -50.859379           30.187500    0.058525
# 16       -47.604167           52.437500    0.054375
# 17              NaN                 NaN         NaN
# 18       -49.718754           45.500004    0.065363
# 19              NaN                 NaN         NaN
# 20       -50.843754           53.625004    0.023655
# 21              NaN                 NaN         NaN
# 22       -63.500000           35.500000         NaN
# 23              NaN                 NaN         NaN
# 24       -52.156250           45.781250    0.035316
# 25       -23.250000           32.000000    0.007522
# 26              NaN                 NaN         NaN
# 27              NaN                 NaN         NaN
# 28              NaN                 NaN         NaN
# 29              NaN                 NaN         NaN
# ...             ...                 ...         ...
# 1940            NaN                 NaN         NaN
# 1941            NaN                 NaN         NaN
# 1942            NaN                 NaN         NaN
# 1943            NaN                 NaN         NaN
# 1944            NaN                 NaN         NaN
# 1945            NaN                 NaN         NaN
# 1946            NaN                 NaN         NaN
# 1947            NaN                 NaN         NaN
# 1948            NaN                 NaN         NaN
# 1949            NaN                 NaN         NaN
# 1950            NaN                 NaN         NaN
# 1951            NaN                 NaN         NaN
# 1952            NaN                 NaN         NaN
# 1953            NaN                 NaN         NaN
# 1954            NaN                 NaN         NaN
# 1955            NaN                 NaN         NaN
# 1956            NaN                 NaN         NaN
# 1957            NaN                 NaN         NaN
# 1958            NaN                 NaN         NaN
# 1959            NaN                 NaN         NaN
# 1960            NaN                 NaN         NaN
# 1961            NaN                 NaN         NaN
# 1962            NaN                 NaN         NaN
# 1963            NaN                 NaN         NaN
# 1964            NaN                 NaN         NaN
# 1965            NaN                 NaN         NaN
# 1966            NaN                 NaN         NaN
# 1967            NaN                 NaN         NaN
# 1968            NaN                 NaN         NaN
# 1969            NaN                 NaN         NaN
#
# [1970 rows x 56 columns]

# %%
q = """
SELECT cell.name,
cell.id,
proj.code,
ef.*
FROM specimens cell 
JOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id
JOIN projects proj ON cell.project_id = proj.id
LEFT JOIN ephys_features ef on ef.specimen_id = cell.id
WHERE proj.code = 'H301'"""

lims_df = get_lims_dataframe(q)
lims_df
# Out:
#            tau  code  thumbnail_sweep_id has_delay  threshold_v_ramp  \
# 0              41.421876                        2.987071  0.069023
# 1              51.906252                        4.312684  0.114468
# 2              45.025000                        3.692418  0.045291
# 3              42.739585                        3.303472  0.074271
# 4              37.742189                        3.548556  0.173008
# 5              27.681252                        2.554582  0.072103
# 6              37.681252                        3.651213  0.154392
# 7              36.875002                        3.392293  0.214776
# 8              40.333335                        2.268135  0.289759
# 9              34.864583                        2.869977  0.117780
# 10                   NaN                             NaN       NaN
# 11             27.414064                        0.936900  0.079550
# 12             33.460939                        0.996052  0.268673
# 13             24.710938                        1.000788  0.062578
# 14             40.231252                        2.717681  0.058092
# 15             43.056252                        3.120868  0.149665
# 16                   NaN                             NaN       NaN
# 17                   NaN                             NaN       NaN
# 18             25.296876                        2.920293  0.071257
# 19             19.156250                        1.450534  0.124376
# 20             44.493752                        2.645823  0.096006
# 21             32.706252                        4.444575  0.072671
# 22                   NaN                             NaN       NaN
# 23             13.243750                        1.303232  0.063368
# 24             48.166669                        2.741129  0.101578
# 25             44.343751                        2.968272  0.070661
# 26             31.581251                        2.621961  0.072206
# 27             27.463543                        1.349027  0.091203
# 28             40.662502                        3.535138  0.158499
# 29             19.148438                        3.996877  0.070819
# ..                   ...                             ...       ...
# 870            39.781252                        2.520905  0.043922
# 871            18.558036                        2.071592  0.242862
# 872                  NaN                             NaN       NaN
# 873                  NaN                             NaN       NaN
# 874            30.734376                        1.583851  0.130771
# 875            34.843752                        2.684514  0.305577
# 876            28.612502                        2.459600  0.119877
# 877            46.100002                        3.643528  0.040478
# 878            39.368751                        2.988413  0.046612
# 879            51.479169                        3.187735  0.014462
# 880            29.828126                        1.825245  0.189766
# 881            43.710939                        2.755450  0.182367
# 882            46.412503                        3.769972  0.150381
# 883                  NaN                             NaN       NaN
# 884            42.125000                        3.484344  0.046707
# 885            31.406250                        2.617419  0.083330
# 886            19.656251                        1.760854  0.081936
# 887            54.000000                        5.494030  0.164662
# 888                  NaN                             NaN       NaN
# 889                  NaN                             NaN       NaN
# 890            44.833333                        2.658374  0.072885
# 891            14.773438                        1.019830  0.162206
# 892             9.578125                        1.345630  0.098656
# 893            22.000000                        1.230919  0.074056
# 894            19.421876                        0.893311  0.088340
# 895                  NaN                             NaN       NaN
# 896            29.212502                        1.289294  0.079153
# 897            27.175002                        2.502346  0.021853
# 898                  NaN                             NaN       NaN
# 899            35.500000                        2.435245  0.086816
#
#                     updated_at  threshold_t_ramp     ...      f_i_curve_slope  \
# 0   2017-09-06 19:40:25.758759         12.466328     ...             0.027053
# 1   2017-06-05 18:17:56.089882         22.377955     ...             0.012500
# 2   2017-06-05 18:18:45.184823          1.812767     ...             0.301339
# 3   2017-08-09 00:38:16.950453          4.600962     ...             0.080120
# 4   2017-06-05 18:16:28.622000          7.137367     ...             0.057753
# 5   2017-06-05 18:17:57.950842          8.591112     ...             0.124482
# 6   2018-03-01 00:52:22.751811          8.604432     ...             0.153409
# 7   2017-06-05 18:19:36.143466          2.618160     ...             0.208838
# 8   2017-06-05 18:17:28.494362          5.146210     ...             0.194643
# 9   2018-08-28 03:24:18.245549         12.061787     ...             0.072876
# 895                        NaT                NaN       NaN
# 896 2017-10-17 06:57:24.929987           1.070220  0.021580
# 897 2017-10-17 20:12:54.384870           1.118460  0.046640
# 898                        NaT                NaN       NaN
# 899 2017-10-17 20:12:34.424192           1.071220  0.023040
#
#      fast_trough_v_long_square  slow_trough_v_ramp  \
# 0                   -50.968750          -58.958337
# 1                   -51.531250          -54.697920
# 2                   -51.718754                 NaN
# 3                   -52.593754          -58.197919
# 4                   -51.750004          -56.072919
# 5                   -45.093754          -49.510419
# 6                   -55.000004                 NaN
# 7                   -52.906254          -58.354168
# 8                   -53.281250          -54.031251
# 9                   -55.218754                 NaN
# 10                         NaN                 NaN
# 11                  -68.250000                 NaN
# 12                  -52.906254                 NaN
# 13                  -62.187504                 NaN
# 14                  -60.187504          -58.000002
# 15                  -52.343754          -55.385420
# 16                         NaN                 NaN
# 17                         NaN                 NaN
# 18                  -52.781254          -53.093754
# 19                  -63.781254          -62.484377
# 20                  -55.937504                 NaN
# 21                  -47.656254                 NaN
# 22                         NaN                 NaN
# 23                  -61.000000                 NaN
# 24                  -48.281254          -49.979168
# 25                  -53.718754                 NaN
# 26                  -60.843754                 NaN
# 27                  -63.406250                 NaN
# 28                  -54.000000                 NaN
# 29                  -41.531254          -42.843750
# ..                         ...                 ...
# 870                 -62.593750          -63.906253
# 871                 -63.218750          -63.203129
# 872                        NaN                 NaN
# 873                        NaN                 NaN
# 874                 -65.656250          -69.375000
# 875                 -64.125000          -62.864586
# 876                 -48.750004          -55.453129
# 877                 -54.937504                 NaN
# 878                 -54.468750          -55.083337
# 879                 -49.781250          -55.354169
# 880                 -60.093754                 NaN
# 881                 -48.062504          -44.968752
# 882                 -46.562504          -50.593752
# 883                        NaN                 NaN
# 884                 -55.875004          -55.187500
# 885                 -53.968754          -53.187500
# 886                 -62.937504                 NaN
# 887                 -51.125000          -51.843750
# 888                        NaN                 NaN
# 889                        NaN                 NaN
# 890                 -48.718750          -51.239587
# 891                 -63.281254          -61.656251
# 892                 -55.562504                 NaN
# 893                 -61.468754                 NaN
# 894                 -64.625000                 NaN
# 895                        NaN                 NaN
# 896                 -58.875004          -59.833337
# 897                 -50.156250          -51.187504
# 898                        NaN                 NaN
# 899                 -54.687504                 NaN
#
#      upstroke_downstroke_ratio_long_square  trough_v_ramp  peak_v_long_square  \
# 0                                 3.558154     -58.958337           38.156254
# 1                                 4.091862     -55.197919           54.843754
# 2                                 3.213940     -50.468751           47.750004
# 3                                 3.397767     -58.197919           43.062500
# 4                                 3.776687     -56.072919           41.781250
# 5                                 2.858349     -49.510419           28.062502
# 6                                 3.788291     -56.312504           37.906250
# 7                                 3.234728     -58.354168           31.468752
# 8                                 2.373951     -55.489587           41.031254
# 9                                 3.029907     -59.895836           35.781254
# 10                                     NaN            NaN                 NaN
# 11                                1.159574     -64.750003           23.062502
# 12                                1.559459     -51.020836           26.250002
# 13                                1.281448     -57.828129           24.375002
# 14                                2.893731     -59.593754           43.625000
# 15                                3.922756     -55.385420           48.062504
# 16                                     NaN            NaN                 NaN
# 17                                     NaN            NaN                 NaN
# 18                                2.617966     -53.093754           26.250002
# 19                                1.404495     -62.484377           14.218750
# 20                                2.570779     -57.989587           43.500004
# 21                                4.278992     -48.333335           36.875004
# 22                                     NaN            NaN                 NaN
# 23                                1.434931     -61.791669            7.656250
# 24                                2.732331     -50.020836           49.781250
# 25                                2.872231     -52.937504           43.937500
# 26                                2.554880     -62.734377           32.625000
# 27                                1.524543     -62.979169           22.031252
# 28                                3.377114     -56.125000           42.437500
# 29                                4.911963     -42.843750          -29.406252
# ..                                     ...            ...                 ...
# 870                               2.536412     -63.906253           36.687500
# 871                               2.204275     -63.203129           24.593752
# 872                                    NaN            NaN                 NaN
# 873                                    NaN            NaN                 NaN
# 874                               1.604161     -69.375000           32.500004
# 875                               2.770107     -62.864586           37.968750
# 876                               2.550157     -55.453129           30.500002
# 877                               3.338498     -57.479169           43.343754
# 878                               2.917104     -55.083337           39.250000
# 879                               3.176452     -55.354169           50.468754
# 880                               2.172128     -60.140629           29.218752
# 881                               2.911801     -44.968752           41.875000
# 882                               3.737607     -50.593752           45.375000
# 883                                    NaN            NaN                 NaN
# 884                               3.596728     -55.187500           42.343750
# 885                               2.600957     -53.187500           34.656254
# 886                               1.749291     -65.270836           22.406250
# 887                               5.661738     -51.843750           52.468754
# 888                                    NaN            NaN                 NaN
# 889                                    NaN            NaN                 NaN
# 890                               2.830538     -51.239587           43.656254
# 891                               1.127131     -61.656251            7.562500
# 892                               1.412368     -58.166670            6.843750
# 893                               1.607723     -61.729169           20.562502
# 894                               1.432385     -60.395837           13.500000
# 895                                    NaN            NaN                 NaN
# 896                               1.593660     -59.833337           34.156250
# 897                               2.582438     -51.906253           26.312502
# 898                                    NaN            NaN                 NaN
# 899                               2.632948     -55.593754           34.031254
#
#      adaptation
# 0           NaN
# 1           NaN
# 2      0.015221
# 3      0.741967
# 4           NaN
# 5      0.053199
# 6      0.187289
# 7      0.035458
# 8      0.110072
# 9           NaN
# 10          NaN
# 11     0.024486
# 12          NaN
# 13     0.052083
# 14     0.050143
# 15     0.249257
# 16          NaN
# 17          NaN
# 18     0.025467
# 19     0.035175
# 20     0.033502
# 21     0.083466
# 22          NaN
# 23          NaN
# 24     0.022702
# 25     0.033226
# 26     0.059769
# 27          NaN
# 28     0.891342
# 29     0.062599
# ..          ...
# 870    0.006021
# 871    0.007626
# 872         NaN
# 873         NaN
# 874    0.006221
# 875    0.010012
# 876    0.052724
# 877         NaN
# 878    0.017659
# 879         NaN
# 880    0.020723
# 881   -0.030222
# 882    0.232891
# 883         NaN
# 884    0.041278
# 885    0.040174
# 886    0.033373
# 887         NaN
# 888         NaN
# 889         NaN
# 890    0.056912
# 891    0.000475
# 892         NaN
# 893         NaN
# 894    0.001101
# 895         NaN
# 896         NaN
# 897    0.076315
# 898         NaN
# 899    0.060345
#
# [900 rows x 56 columns]

# %%
lims_df.to_csv('ME_200501.csv')

# %% [markdown]
# # Obtain mapping data from shiny, stored on the network

# %%
#sncg1= pd.read_csv('soltesz_sncg_shiny_data.csv')
sncg1= pd.read_csv('soltesz_sncg_shiny_data_200406.csv')
sncg2= pd.read_csv('soltesz_slc_sncg_shiny_data.csv')
#mouse_hip = pd.concat([sncg1,sncg2])
mouse_hip = pd.read_csv('visp_sncg_200413.csv')
culture = pd.read_csv('culture_200415.csv')
mouse = pd.read_csv('mouse_200416.csv')
mouse = pd.read_csv('all_mouse_regions.csv')
human_lockdown = pd.read_csv('MET_METc_lockdown_data.csv')

# %%
#shiny_df = pd.read_csv("\\\\allen\\programs\\celltypes\\workgroups\\279\\IVSCC_KPIs\\\shiny_LIMS.csv")
#shiny_df = pd.read_csv('human_shiny_200127.csv')
#shiny_df = pd.read_csv('ps_no_exc23 (metx).csv')
shiny_df = human_lockdown
shiny_df
# Out:
#      Unnamed: 0  spec_id_label    subclass_label  \
# 0           577      923121427  LAMP5/PAX6/Other
# 1           211      911022014  LAMP5/PAX6/Other
# 2           244      910987373  LAMP5/PAX6/Other
# 3             1      884889997  LAMP5/PAX6/Other
# 4           223      880209696  LAMP5/PAX6/Other
# 5           224      857542109  LAMP5/PAX6/Other
# 6             4      854597364  LAMP5/PAX6/Other
# 7           502      840131814  LAMP5/PAX6/Other
# 8           536      787132331  LAMP5/PAX6/Other
# 9           225      766787898  LAMP5/PAX6/Other
# 10          231      750841036  LAMP5/PAX6/Other
# 11          566      721577859  LAMP5/PAX6/Other
# 12          128      720804117  LAMP5/PAX6/Other
# 13          313      720777847  LAMP5/PAX6/Other
# 14          517      720836999  LAMP5/PAX6/Other
# 15           68      712874974  LAMP5/PAX6/Other
# 16          220      712901159  LAMP5/PAX6/Other
# 17          100      700825191  LAMP5/PAX6/Other
# 18          510      696099874  LAMP5/PAX6/Other
# 19          521      696105256  LAMP5/PAX6/Other
# 20           20      689331715  LAMP5/PAX6/Other
# 21          177      674650891  LAMP5/PAX6/Other
# 22          221      672659031  LAMP5/PAX6/Other
# 23          534      672652822  LAMP5/PAX6/Other
# 24          226      672324078  LAMP5/PAX6/Other
# 25            8      665695769  LAMP5/PAX6/Other
# 26           88      653796765  LAMP5/PAX6/Other
# 27           69      653818084  LAMP5/PAX6/Other
# 28           81      653890370  LAMP5/PAX6/Other
# 29          590      653791870  LAMP5/PAX6/Other
# ..          ...            ...               ...
# 820         696      960843637               SST
# 821         274      696108575               VIP
# 822         283      689319155               VIP
# 823         507      685766680               VIP
# 824         850      819074590             PVALB
# 825         725      819106998             PVALB
# 826         588      685771025               VIP
# 827         535      685780246               VIP
# 828         564      685806972               VIP
# 829         176      685785495               VIP
# 830         187      677063468               VIP
# 831         479      672646211               VIP
# 832         835      819116654               SST
# 833         611      819133824  LAMP5/PAX6/Other
# 834         529      672655512               VIP
# 835         310      666068044               VIP
# 836         532      665718254               VIP
# 837         823      819166048               SST
# 838         716      819177874             PVALB
# 839         807      819185246  LAMP5/PAX6/Other
# 840         825      819191383               SST
# 841         169      665700287               VIP
# 842         480      665695931               VIP
# 843         605      819197541             PVALB
# 844         302      653882762               VIP
# 845         481      653038959               VIP
# 846         543      652069520               VIP
# 847         297      650130090               VIP
# 848         154      650074908               VIP
# 849         538      650077366               VIP
#
#               seurat_cluster_label            Tree_first_cl_label  \
# 0              Inh L5-6 PVALB LGR5   Inh L1-2 SST BAGE2 (ADARB2+)
# 1              Inh L1-2 PAX6 CDH12            Inh L1-2 PAX6 CDH12
# 2    Inh L1-4 LAMP5 LCP2 (rosehip)  Inh L1-4 LAMP5 LCP2 (rosehip)
# 3             Inh L2-4 PVALB WFDC2        Inh L1-2 PAX6 TNFAIP8L3
# 4               Inh L1-3 SST CALB1      Inh L2-6 LAMP5 CA1 (Igtp)
# 5            Inh L1-3 VIP ADAMTSL1            Inh L1-2 PAX6 CDH12
# 6                Exc L4-6 RORB C1R            Inh L1-2 PAX6 CDH12
# 7               Inh L1-3 SST CALB1  Inh L1-4 LAMP5 LCP2 (rosehip)
# 8         Exc L2-3 LINC00507 FREM3      Inh L1 SST NMBR (ADARB2+)
# 9         Exc L2-3 LINC00507 FREM3            Inh L1-2 PAX6 CDH12
# 10             Inh L4-5 PVALB MEPE            Inh L1-2 PAX6 CDH12
# 11              Inh L1-2 LAMP5 DBP  Inh L1-4 LAMP5 LCP2 (rosehip)
# 12            Inh L2-4 PVALB WFDC2      Inh L2-6 LAMP5 CA1 (Igtp)
# 13               Exc L4-6 RORB C1R      Inh L2-6 LAMP5 CA1 (Igtp)
# 14             Exc L4-5 RORB DAPK2            Inh L1-2 PAX6 CDH12
# 15              Inh L1-3 SST CALB1   Inh L1-2 GAD1 MC4R (ADARB2+)
# 16              Inh L1-3 SST CALB1  Inh L1-4 LAMP5 LCP2 (rosehip)
# 17             Inh L5-6 PVALB LGR5  Inh L1-4 LAMP5 LCP2 (rosehip)
# 18            Inh L2-4 PVALB WFDC2            Inh L1-2 PAX6 CDH12
# 19             Inh L4-5 PVALB MEPE  Inh L1-4 LAMP5 LCP2 (rosehip)
# 20                Exc L2 LAMP5 LTK  Inh L1-4 LAMP5 LCP2 (rosehip)
# 21             Inh L1-2 PAX6 CDH12            Inh L1-2 PAX6 CDH12
# 22             Inh L1-2 PAX6 CDH12            Inh L1-2 PAX6 CDH12
# 23           Inh L5-6 SST MIR548F2    Inh L1 SST CHRNA4 (ADARB2+)
# 24        Exc L2-3 LINC00507 FREM3  Inh L1-4 LAMP5 LCP2 (rosehip)
# 25              Inh L1-2 LAMP5 DBP  Inh L1-4 LAMP5 LCP2 (rosehip)
# 26            Inh L2-4 PVALB WFDC2            Inh L1-2 PAX6 CDH12
# 27        Exc L2-3 LINC00507 FREM3  Inh L1-4 LAMP5 LCP2 (rosehip)
# 28             Inh L3-5 SST ADGRG6   Inh L1-2 SST BAGE2 (ADARB2+)
# 29                Exc L2 LAMP5 LTK  Inh L1-4 LAMP5 LCP2 (rosehip)
# ..                             ...                            ...
# 820             Inh L1-3 SST CALB1                Inh L5-6 SST TH
# 821          Inh L3-6 VIP HS3ST3A1             Inh L1-4 VIP OPRM1
# 822          Inh L1-3 VIP ADAMTSL1          Inh L1-3 VIP ADAMTSL1
# 823           Inh L1-3 VIP CCDC184           Inh L1-3 VIP CCDC184
# 824           Inh L2-4 PVALB WFDC2            Inh L4-5 PVALB MEPE
# 825           Inh L2-4 PVALB WFDC2           Inh L2-4 PVALB WFDC2
# 23                      False           PoorQ  H18.03.004    Acute
# 24                      False           PoorQ  H18.06.004    Acute
# 25                      False           PoorQ  H18.03.003    Acute
# 26                      False           PoorQ  H17.03.016    Acute
# 27                      False           PoorQ  H17.03.016    Acute
# 28                      False           PoorQ  H17.03.016    Acute
# 29                      False           PoorQ  H17.03.016    Acute
# ..                        ...             ...         ...      ...
# 820                     False           PoorQ  H19.26.405  Culture
# 821                      True           PoorQ  H18.03.010    Acute
# 822                      True              I2  H18.03.009    Acute
# 823                      True            Core  H18.03.008    Acute
# 824                      True              I3  H19.03.002  Culture
# 825                      True            Core  H19.03.002  Culture
# 826                      True            Core  H18.03.008    Acute
# 827                      True            Core  H18.03.008    Acute
# 828                      True            Core  H18.03.008    Acute
# 829                      True           PoorQ  H18.03.008    Acute
# 830                      True           PoorQ  H18.03.006    Acute
# 831                      True            Core  H18.03.004    Acute
# 832                      True            Core  H19.03.002  Culture
# 833                      True           PoorQ  H19.03.002  Culture
# 834                      True           PoorQ  H18.03.004    Acute
# 835                      True              I1  H18.03.003    Acute
# 836                      True              I1  H18.03.003    Acute
# 837                      True              I1  H19.03.002  Culture
# 838                      True            Core  H19.03.002  Culture
# 839                      True            Core  H19.03.002  Culture
# 840                      True              I1  H19.03.002  Culture
# 841                      True           PoorQ  H18.03.003    Acute
# 842                      True              I1  H18.03.003    Acute
# 843                      True           PoorQ  H19.03.002  Culture
# 844                      True              I1  H17.03.016    Acute
# 845                      True              I1  H17.26.005    Acute
# 846                      True            Core  H17.06.015    Acute
# 847                      True            Core  H17.26.003    Acute
# 848                      True              I2  H17.26.003    Acute
# 849                      True            Core  H17.26.003    Acute
#
#                sample_id            cell_name_label  DIV   Virus    date
# 0    PES4_190813_659_A01     H19.03.319.11.11.01.04  NaN     NaN  190813
# 1    PAS4_190723_451_A01     H19.03.317.11.06.01.02  NaN     NaN  190723
# 2    PES4_190723_651_A01     H19.03.317.11.10.01.01  NaN     NaN  190723
# 3    P1S4_190611_005_A01     H19.26.403.11.12.01.01  NaN     NaN  190611
# 4    P1S4_190603_002_A01     H19.06.356.11.08.01.02  NaN     NaN  190603
# 5    PES4_190425_651_A01     H19.03.310.11.06.01.01  NaN     NaN  190425
# 6    P1S4_190419_004_A01     H19.03.309.11.08.01.04  NaN     NaN  190419
# 7    PES4_190321_659_A01     H19.06.351.11.10.01.10  NaN     NaN  190321
# 8    PBS4_181128_502_A01     H18.03.322.11.16.01.02  NaN     NaN  181128
# 9    PES4_181022_655_A01     H18.06.366.15.05.01.01  NaN     NaN  181022
# 10   PES4_180911_662_A01     H18.03.316.11.11.01.01  NaN     NaN  180911
# 11   P8S4_180718_352_A01     H18.03.313.11.06.01.02  NaN     NaN  180718
# 12   P2S4_180717_061_A01     H18.26.405.11.15.01.04  NaN     NaN  180717
# 13   P8S4_180717_358_A01     H18.26.405.12.04.01.02  NaN     NaN  180717
# 14   PBS4_180717_508_A01     H18.03.313.11.16.01.02  NaN     NaN  180717
# 15   P9S4_180621_402_A01     H18.26.403.11.02.01.02  NaN     NaN  180621
# 16   P9S4_180621_406_A01     H18.26.403.11.02.01.07  NaN     NaN  180621
# 17   P8S4_180522_356_A01     H18.03.012.11.11.01.04  NaN     NaN  180522
# 18   PBS4_180508_507_A01        H18.03.010.11.11.01  NaN     NaN  180508
# 19   PBS4_180508_511_A01        H18.03.010.11.11.05  NaN     NaN  180508
# 20   P2S4_180424_059_A01        H18.03.009.11.15.05  NaN     NaN  180424
# 21   P8S4_180320_362_A01        H18.03.005.11.12.06  NaN     NaN  180320
# 22   P9S4_180313_408_A01        H18.03.004.11.14.04  NaN     NaN  180313
# 23   PBS4_180313_507_A01        H18.03.004.11.11.03  NaN     NaN  180313
# 24   P8S4_180312_355_A01        H18.06.004.11.02.03  NaN     NaN  180312
# 25   P1S4_180220_001_A01        H18.03.003.11.02.01  NaN     NaN  180220
# 26   P8S4_171219_354_A01        H17.03.016.11.15.02  NaN     NaN  171219
# 27   P8S4_171219_356_A01        H17.03.016.11.15.04  NaN     NaN  171219
# 28   P8S4_171219_358_A01        H17.03.016.11.15.06  NaN     NaN  171219
# 29   P9S4_171219_401_A01        H17.03.016.11.10.01  NaN     NaN  171219
# ..                   ...                        ...  ...     ...     ...
# 820  PCS4_191003_354_A01     H19.26.405.12.56.01.04  4.0  CN1390  191003
# 821  PBS4_180508_513_A01        H18.03.010.11.11.07  NaN     NaN  180508
# 822  P8S4_180424_361_A01        H18.03.009.11.16.05  NaN     NaN  180424
# 823  P8S4_180417_359_A01        H18.03.008.11.12.01  NaN     NaN  180417
# 824  PXS4_190125_351_A01  h19.03.002.12.01.01.01.01  3.0  CN1390  190125
# 825  PXS4_190125_352_A01  h19.03.002.12.01.01.01.02  3.0  CN1390  190125
# 826  P8S4_180417_361_A01        H18.03.008.11.12.03  NaN     NaN  180417
# 827  P8S4_180417_362_A01        H18.03.008.11.12.04  NaN     NaN  180417
# 828  P8S4_180417_365_A01        H18.03.008.11.12.07  NaN     NaN  180417
# 829  PBS4_180417_512_A01        H18.03.008.11.14.04  NaN     NaN  180417
# 830  P8S4_180327_357_A01        H18.03.006.11.04.04  NaN     NaN  180327
# 831  P9S4_180313_406_A01        H18.03.004.11.14.01  NaN     NaN  180313
# 832  PXS4_190125_353_A01  h19.03.002.12.01.01.01.03  3.0  CN1390  190125
# 833  PXS4_190125_354_A01  h19.03.002.12.01.01.01.04  3.0  CN1390  190125
# 834  PBS4_180313_508_A01        H18.03.004.11.11.04  NaN     NaN  180313
# 835  PBS4_180221_501_A01        H18.03.003.12.01.01  NaN     NaN  180221
# 836  P1S4_180220_003_A01        H18.03.003.11.02.03  NaN     NaN  180220
# 837  PXS4_190125_355_A01  h19.03.002.12.01.01.01.05  3.0  CN1390  190125
# 838  PXS4_190125_356_A01  h19.03.002.12.01.01.01.06  3.0  CN1390  190125
# 839  PXS4_190125_358_A01  h19.03.002.12.01.01.01.08  3.0  CN1390  190125
# 840  PXS4_190125_359_A01  h19.03.002.12.01.01.01.09  3.0  CN1390  190125
# 841  P2S4_180220_057_A01        H18.03.003.11.04.01  NaN     NaN  180220
# 842  P8S4_180220_357_A01        H18.03.003.11.05.01  NaN     NaN  180220
# 843  PXS4_190125_360_A01  h19.03.002.12.01.01.01.10  3.0  CN1390  190125
# 844  P2S4_171219_057_A01        H17.03.016.11.04.06  NaN     NaN  171219
# 845  P2S4_171212_055_A01        H17.26.005.11.09.03  NaN     NaN  171212
# 846  P8S4_171205_351_A01        H17.06.015.13.08.01  NaN     NaN  171205
# 847  P2S4_171128_051_A01        H17.26.003.12.12.01  NaN     NaN  171128
# 848  P8S4_171127_352_A01        H17.26.003.11.16.02  NaN     NaN  171127
# 849  P8S4_171127_354_A01        H17.26.003.11.16.04  NaN     NaN  171127
#
# [850 rows x 14 columns]

# %%
shiny_df['spec_id_label']
# Out:
# 0      923121427
# 1      911022014
# 2      910987373
# 3      884889997
# 4      880209696
# 5      857542109
# 6      854597364
# 7      840131814
# 8      787132331
# 9      766787898
# 10     750841036
# 11     721577859
# 12     720804117
# 13     720777847
# 14     720836999
# 15     712874974
# 16     712901159
# 17     700825191
# 18     696099874
# 19     696105256
# 20     689331715
# 21     674650891
# 22     672659031
# 23     672652822
# 24     672324078
# 25     665695769
# 26     653796765
# 27     653818084
# 28     653890370
# 29     653791870
#          ...
# 820    960843637
# 821    696108575
# 822    689319155
# 823    685766680
# 824    819074590
# 825    819106998
# 826    685771025
# 827    685780246
# 828    685806972
# 829    685785495
# 830    677063468
# 831    672646211
# 832    819116654
# 833    819133824
# 834    672655512
# 835    666068044
# 836    665718254
# 837    819166048
# 838    819177874
# 839    819185246
# 840    819191383
# 841    665700287
# 842    665695931
# 843    819197541
# 844    653882762
# 845    653038959
# 846    652069520
# 847    650130090
# 848    650074908
# 849    650077366
# Name: spec_id_label, dtype: int64

# %% [markdown]
# # Merge LIMS and Shiny dataframes, save to csv

# %%
ephys_shiny_df = pd.merge(left = lims_df, 
                    right = shiny_df, 
                    left_on = 'name', #ephys
                    right_on = 'cell_name_label', #shiny
                    how = 'left')

# %%
ephys_shiny_df = pd.merge(left = shiny_df, 
                    right = lims_df, 
                    left_on = 'cell_name_label', #shiny
                    right_on = 'name', #ephys
                    how = 'left')

# %%
mouse_ids = ephys_shiny_df[['specimen_id_x','subclass_label']]
mouse_ids.to_csv('human_ids191211.csv')

# %%
ephys_shiny_df.to_csv("all_mouse_regions_ephys_200417.csv")

# %%
ephys_shiny_df.to_csv("MET_data_191101.csv")

# %%
ephys_shiny_df.to_csv('culture_patchseq_data_200219.csv')

# %%
ephys_shiny_df['subclass_label'].unique()
# Out:
# array(['LAMP5/PAX6/Other', 'SST', 'PVALB', 'VIP'], dtype=object)

# %%
ephys_shiny_df.to_csv('human_200326.csv')

# %%
ephys_shiny_df.to_csv('mouse_hip_200406.csv')

# %%
ephys_shiny_df.to_csv('visp_sncg_200414.csv')

# %%
ephys_shiny_df = pd.merge(left = lims_df, 
                    right = shiny_df, 
                    left_on = 'name', #ephys
                    right_on = 'cell_name', #shiny
                    how = 'left')

# %%
test = lims_df[lims_df['name'] == 'H17.06.007.11.05.04']
test.to_csv("test200508.csv")

# %%
ephys_shiny_df.to_csv('human_lockdown_shiny_ephys.csv')
