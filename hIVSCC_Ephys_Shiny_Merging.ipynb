# %% [markdown]
# # Imports and Functions

# %%
import pg8000
import pandas as pd    
import os, re
import numpy as np
import matplotlib.pyplot as plt
from allensdk.core.nwb_data_set import NwbDataSet
import allensdk.ephys.ephys_features as aef
import allensdk.ephys.extract_cell_features as ecf
import seaborn as sns
#from research_ops_tools.lims2_funcs import get_lims_dataframe
#from allensdk.internal.core.lims_utilities import linux_to_windows

import warnings
warnings.filterwarnings('ignore')

sns.set()

# %%
#code from Agata
#these are nice functions to open LIMS, make a query and then close LIMS after

def _connect(user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    conn = pg8000.connect(user=user, host=host, database=database, password=password, port=port)
    return conn, conn.cursor()

def _select(cursor, query):
    cursor.execute(query)
    columns = [ d[0] for d in cursor.description ]
    return [ dict(zip(columns, c)) for c in cursor.fetchall() ]

def limsquery(query, user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    """A function that takes a string containing a SQL query, connects to the LIMS database and outputs the result."""
    conn, cursor = _connect(user, host, database, password, port)
    try:
        results = _select(cursor, query)
    finally:
        
        #THESE ARE IMPORTANT!!!!!!
        #Every query needs to be closed when done
        cursor.close()             
        conn.close()
    return results


#this last function will take our query results and put them in a dataframe so that they are easy to work with
def get_lims_dataframe(query):
    '''Return a dataframe with lims query'''
    result = limsquery(query)
    try:
        data_df = pd.DataFrame(data=result, columns=result[0].keys())
    except IndexError:
        print "Could not find results for your query."
        data_df = pd.DataFrame()
    return data_df

# %% [markdown]
# # Obtain ephys data from LIMS

# %%
q = """
SELECT cell.name,
cell.id,
SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) AS container_date,
ef.*
FROM specimens cell 
JOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id
JOIN projects proj ON cell.project_id = proj.id
LEFT JOIN ephys_features ef on ef.specimen_id = cell.id
WHERE SUBSTRING(cell.patched_cell_container FROM 6 FOR 6) BETWEEN '180101' AND '190830'
AND proj.code in ('mIVSCC-MET', 'T301')"""

lims_df = get_lims_dataframe(q)
lims_df
# Out:
#             tau  upstroke_downstroke_ratio_short_square  thumbnail_sweep_id  \
# 0     20.155605                                2.161662         861091259.0
# 1           NaN                                     NaN                 NaN
# 2      9.199781                                3.582439         861090559.0
# 3           NaN                                     NaN                 NaN
# 4      9.319132                                1.592834         861091394.0
# 5      8.374705                                3.763035         861091396.0
# 6     12.350084                                1.887376         861090329.0
# 7     17.099053                                1.769058         861090429.0
# 8           NaN                                     NaN                 NaN
# 9     25.138305                                1.871368         861090527.0
# 10    13.905170                                1.781022         861090875.0
# 11          NaN                                     NaN                 NaN
# 12    16.823345                                1.783498         861091906.0
# 13    31.647042                                2.450621         861091129.0
# 14    28.506419                                3.246413         890119100.0
# 15          NaN                                     NaN                 NaN
# 16     4.608558                                1.615950         861091296.0
# 17          NaN                                     NaN                 NaN
# 18    23.409767                                3.306003         861091580.0
# 19          NaN                                     NaN                 NaN
# 20          NaN                                     NaN                 NaN
# 21          NaN                                     NaN                 NaN
# 22     7.639355                                1.720984         861082241.0
# 23          NaN                                     NaN                 NaN
# 24          NaN                                     NaN                 NaN
# 25          NaN                                     NaN                 NaN
# 26          NaN                                     NaN                 NaN
# 27          NaN                                     NaN                 NaN
# 28     8.972276                                2.980405         861082244.0
# 29    22.048558                                2.058788         861082555.0
# ...         ...                                     ...                 ...
# 6165  16.061453                                3.775486         934880889.0
# 6166  21.247596                                4.371710         934922370.0
# 6167  17.205486                                3.922008         934922535.0
# 6168  29.368270                                3.426511         935069235.0
# 6169  22.403060                                2.453871         935033595.0
# 6170  26.350235                                2.539193         935136923.0
# 6171  14.020000                                4.574516         935098075.0
# 6172  15.297316                                2.695546         935136993.0
# 6173  30.542039                                2.437407         935137080.0
# 6174  13.614033                                3.269131         935208629.0
# 6175  28.444378                                2.982151         935194333.0
# 6176  13.678900                                3.875783         935219706.0
# 6177  14.819237                                3.014875         935208676.0
# 6178  16.721672                                2.553527         935220343.0
# 6179  12.664239                                2.877148         935224673.0
# 6180  11.994183                                4.506343         935799448.0
# 6181  11.523140                                4.274239         935798020.0
# 6182   8.920938                                2.555562         935798362.0
# 6183        NaN                                     NaN                 NaN
# 6184  20.110614                                3.269451         935846018.0
# 6185  12.696251                                1.896936         935846017.0
# 6186   7.092067                                1.286782         935898528.0
# 6187  12.430844                                1.739280         935918159.0
# 6188   9.353220                                4.488979         936057441.0
# 6189  22.495953                                2.472564         936073532.0
# 6190  31.944696                                2.800155         936096256.0
# 6191  24.386413                                3.409860         936073354.0
# 6192        NaN                                     NaN                 NaN
# 6193   9.276725                                2.683637         936096067.0
# 6194  17.161129                                3.185502         936147591.0
#
#      has_delay  threshold_v_ramp  peak_v_short_square  \
# 0         None        -41.937500            32.906250
# 1         None               NaN                  NaN
# 2         None        -37.781250            22.385417
# 3         None               NaN                  NaN
# 4         None        -33.890625            31.687500
# 5         None        -25.984375            37.293751
# 6         None        -41.656250             8.468750
# 7         None        -61.343750            25.000000
# 8         None               NaN                  NaN
# 9         None        -30.656250            39.687500
# 10        None        -23.046875            29.648438
# 11        None               NaN                  NaN
# 12        None        -26.687500            24.062500
# 13        None        -39.750000            17.312500
# 14        None        -46.906250            29.020834
# 15        None               NaN                  NaN
# 16        None        -19.031250            22.531250
# 17        None               NaN                  NaN
# 18        None        -11.875000            47.024307
# 19        None               NaN                  NaN
# 20        None               NaN                  NaN
# 21        None               NaN                  NaN
# 22        None        -28.156250            19.097656
# 23        None               NaN                  NaN
# 24        None               NaN                  NaN
# 25        None               NaN                  NaN
# 26        None               NaN                  NaN
# 27        None               NaN                  NaN
# 28        None        -41.000000            29.687500
# 29        None        -38.109375            23.554688
# ...        ...               ...                  ...
# 6165      None        -36.170834            44.687500
# 6166      None        -29.462500            33.728123
# 6167      None        -34.075001            42.912498
# 6168      None        -27.083334            40.950001
# 6169      None        -29.202085            35.321873
# 6170      None        -41.102081            30.506250
# 6171      None        -38.724995            44.718750
# 6172      None        -41.031250            28.110937
# 6173      None        -22.233332             2.685416
# 6174      None        -30.731249            40.612499
# 6175      None        -25.535936            29.706249
# 6176      None        -38.000000            41.568748
# 6177      None        -35.306248            30.506250
# 6178      None        -30.287500            32.125000
# 6179      None        -30.916666            36.448437
# 6180      None        -23.670832            62.040627
# 6181      None        -37.618748            52.562500
# 6182      None        -33.787498            19.581249
# 6183      None               NaN                  NaN
# 6184      None        -28.702082            40.943748
# 6185      None        -40.049999            35.099998
# 6186      None        -32.704685            31.104687
# 6187      None        -34.212498            31.543749
# 6188      None        -26.720833            53.366249
# 6189      None        -36.329166            31.984997
# 6190      None        -37.565624            42.325001
# 6191      None        -41.560417            38.202084
# 6192      None               NaN                  NaN
# 6193      None        -32.847916            27.637499
# 6194      None        -40.293751            37.949997
#
#       upstroke_downstroke_ratio_ramp       sag                 updated_at  \
# 0                           2.154621  0.003525 2019-05-02 01:16:36.071838
# 1                                NaN       NaN                        NaT
# 2                           3.575613  0.033580 2019-05-02 01:15:17.698290
# 3                                NaN       NaN                        NaT
# 4                           1.172872  0.055818 2019-05-02 01:16:48.807617
# 5                           2.409095  0.059685 2019-05-02 01:16:46.338036
# 6                           1.575830  0.032335 2019-05-02 01:15:01.537859
# 7                           1.867376  0.003167 2019-05-02 01:15:54.452867
# 8                                NaN       NaN                        NaT
# 9                           1.642519  0.029762 2019-05-02 01:16:04.194879
# 10                          1.417837  0.051569 2019-05-02 01:16:44.737027
# 11                               NaN       NaN                        NaT
# 12                          1.796703  0.147931 2019-05-02 01:17:39.452543
# 13                          2.836398  0.069316 2019-05-02 01:16:06.339034
# 14                          3.177397  0.175939 2019-06-19 19:08:36.825475
# 15                               NaN       NaN                        NaT
# 16                          1.377253  0.019107 2019-05-02 01:16:27.029419
# 17                               NaN       NaN                        NaT
# 18                          2.624943  0.071434 2019-05-02 01:17:34.832971
# 19                               NaN       NaN                        NaT
# 20                               NaN       NaN                        NaT
# 21                               NaN       NaN                        NaT
# 22                          1.475904  0.012702 2019-05-02 01:16:25.892396
# 23                               NaN       NaN                        NaT
# 24                               NaN       NaN                        NaT
# 25                               NaN       NaN                        NaT
# 26                               NaN       NaN                        NaT
# 27                               NaN       NaN                        NaT
# 28                          2.672665  0.049359 2019-05-02 01:16:07.856995
# 29                          2.311976  0.132951 2019-05-02 01:16:04.909741
# ...                              ...       ...                        ...
# 6165                        4.435170  0.037701 2019-08-29 19:15:43.428586
# 6166                        5.426056  0.001880 2019-08-29 19:45:14.807941
# 6167                        3.629539  0.027908 2019-08-29 19:45:32.998126
# 6168                        3.342810  0.011519 2019-08-29 21:37:49.622409
# 6169                        3.071030  0.071937 2019-08-29 21:06:20.511891
# 6170                        2.939417  0.073660 2019-08-29 22:16:14.171005
# 6171                        5.021305  0.015121 2019-08-29 21:58:29.982960
# 6172                        4.099532  0.250034 2019-08-29 22:16:12.827206
# 6173                        2.929675  0.040287 2019-08-29 22:16:18.044272
# 6174                        2.885314  0.136096 2019-08-29 23:15:01.294752
# 6175                        3.958198  0.021408 2019-08-29 23:08:30.382610
# 6176                        4.162289  0.055649 2019-08-29 23:15:13.084512
# 6177                        2.820582  0.135531 2019-08-29 23:15:18.896974
# 6178                        2.649817  0.147980 2019-08-29 23:27:18.657687
# 6179                        2.271698  0.106635 2019-08-29 23:32:39.092168
# 6180                        5.163083  0.007922 2019-08-30 18:22:48.134472
# 6181                        5.027562  0.040321 2019-08-30 18:22:38.722147
# 6182                        4.006404  0.053577 2019-08-30 18:22:42.838908
# 6183                             NaN       NaN                        NaT
# 6184                        3.620277  0.054505 2019-08-30 19:22:35.475419
# 6185                        1.550102  0.041275 2019-08-30 19:22:36.840766
# 6186                        1.166303  0.070977 2019-08-30 19:58:13.574994
# 6187                        1.505179  0.057064 2019-08-30 20:17:35.898504
# 6188                        4.394406  0.011989 2019-08-30 21:20:24.549898
# 6189                        2.607242  0.067399 2019-08-30 21:20:32.912265
# 6190                        2.860527  0.071222 2019-08-30 21:53:01.384686
# 6191                        4.195091  0.236517 2019-08-30 21:31:59.183332
# 6192                             NaN       NaN                        NaT
# 6193                        4.157781  0.045548 2019-08-30 21:52:42.852286
# 6194                        3.880275  0.271286 2019-08-30 22:46:07.900525
#
#       threshold_t_ramp     ...      trough_v_short_square  f_i_curve_slope  \
# 0             4.135120     ...                 -73.750000         0.062500
# 1                  NaN     ...                        NaN              NaN
# 2             2.571320     ...                 -69.104164         0.550000
# 3                  NaN     ...                        NaN              NaN
# 4            13.129790     ...                 -66.583336         0.037500
# 5             7.647620     ...                 -72.775000         0.062500
# 6             6.769120     ...                 -68.312500         0.025000
# 7             2.497820     ...                 -76.406250         0.025000
# 8                  NaN     ...                        NaN              NaN
# 9             3.346520     ...                 -55.687500         0.350000
# 10           18.263530     ...                 -66.078125         0.047727
# 11                 NaN     ...                        NaN              NaN
# 12            7.942730     ...                 -69.385417         0.019256
# 13            2.289240     ...                 -66.583336         0.075000
# 14            2.114740     ...                 -62.072918         0.150000
# 15                 NaN     ...                        NaN              NaN
# 16           17.221400     ...                 -71.343750         0.613636
# 17                 NaN     ...                        NaN              NaN
# 18           12.148180     ...                 -68.763889         0.004392
# 19                 NaN     ...                        NaN              NaN
# 20                 NaN     ...                        NaN              NaN
# 21                 NaN     ...                        NaN              NaN
# 22           10.330340     ...                 -69.757812         0.300352
# 23                 NaN     ...                        NaN              NaN
# 24                 NaN     ...                        NaN              NaN
# 25                 NaN     ...                        NaN              NaN
# 26                 NaN     ...                        NaN              NaN
# 27                 NaN     ...                        NaN              NaN
# 28            2.179120     ...                 -61.583332         0.624138
# 29            3.814060     ...                 -71.312500         0.337500
# ...                ...     ...                        ...              ...
# 6165          4.203087     ...                 -76.799995         0.168103
# 6166          4.565807     ...                 -73.595306         0.120000
# 6167          5.267120     ...                 -79.856247         0.130000
# 6168          4.499993     ...                 -69.331245         0.069693
# 6169          4.705253     ...                 -76.425003         0.060233
# 6170          2.032020     ...                 -70.543747         0.263324
# 6171          5.984660     ...                 -83.931252         0.135000
# 6172          8.039120     ...                 -71.148436         0.035937
# 6173          2.920140     ...                 -44.009373         0.194528
# 6174          5.386053     ...                 -74.362495         0.210000
# 6175         10.372290     ...                 -72.799995         0.018557
# 6176         12.237433     ...                 -84.756248         0.107229
# 6177          4.223500     ...                 -74.493752         0.285000
# 6178          5.141127     ...                 -74.824997         0.219828
# 6179          7.284413     ...                 -76.570312         0.185047
# 6180          7.067427     ...                 -72.634377         0.157009
# 6181          6.596780     ...                 -84.118752         0.130000
# 6182          9.189892     ...                 -80.080208         0.128788
# 6183               NaN     ...                        NaN              NaN
# 6184          4.302460     ...                 -73.799995         0.145000
# 6185          6.119573     ...                 -70.046875         0.035345
# 6186         13.876990     ...                 -76.515625         0.775000
# 6187          6.622867     ...                 -74.900002         0.868103
# 6188         12.136207     ...                 -78.642494         0.137255
# 6189          2.106453     ...                 -48.546249         0.322250
# 6190          1.105535     ...                 -61.962498         0.387533
# 6191          2.283313     ...                 -66.193748         0.272127
# 6192               NaN     ...                        NaN              NaN
# 6193          5.827800     ...                 -76.000000         0.310000
# 6194          2.437040     ...                 -64.199997         0.211823
#
#                      created_at  peak_t_long_square  latency  \
# 0    2019-05-02 01:16:36.071838             0.60518  0.02238
# 1                           NaT                 NaN      NaN
# 2    2019-05-02 01:15:17.698290             0.54306  0.04264
# 3                           NaT                 NaN      NaN
# 4    2019-05-02 01:16:48.807617             0.54284  0.01220
# 5    2019-05-02 01:16:46.338036             0.54206  0.01574
# 6    2019-05-02 01:15:01.537859             0.51350  0.00654
# 7    2019-05-02 01:15:54.452867             0.55670  0.01744
# 8                           NaT                 NaN      NaN
# 9    2019-05-02 01:16:04.194879             0.67946  0.02370
# 10   2019-05-02 01:16:44.737027             0.56404  0.03986
# 11                          NaT                 NaN      NaN
# 12   2019-05-02 01:17:39.452543             0.65460  0.06788
# 13   2019-05-02 01:16:06.339034             0.65050  0.03606
# 14   2019-06-19 19:08:36.825475             0.60494  0.02064
# 15                          NaT                 NaN      NaN
# 16   2019-05-02 01:16:27.029419             0.58664  0.03908
# 17                          NaT                 NaN      NaN
# 18   2019-05-02 01:17:34.832971             0.60480  0.08828
# 19                          NaT                 NaN      NaN
# 20                          NaT                 NaN      NaN
# 21                          NaT                 NaN      NaN
# 22   2019-05-02 01:16:25.892396             0.53788  0.01776
# 23                          NaT                 NaN      NaN
# 24                          NaT                 NaN      NaN
# 25                          NaT                 NaN      NaN
# 26                          NaT                 NaN      NaN
# 27                          NaT                 NaN      NaN
# 28   2019-05-02 01:16:07.856995             0.58838  0.00588
# 29   2019-05-02 01:16:04.909741             0.68338  0.04830
# ...                         ...                 ...      ...
# 6165 2019-08-29 19:15:43.428586             0.65988  0.05358
# 6166 2019-08-29 19:36:43.088704             0.72600  0.07786
# 6167 2019-08-29 19:45:32.998126             0.75490  0.07720
# 6168 2019-08-29 20:47:33.487938             0.61236  0.03244
# 6169 2019-08-29 21:06:20.511891             0.73298  0.03836
# 6170 2019-08-29 21:37:30.914528             0.65396  0.02236
# 6171 2019-08-29 21:58:29.982960             0.82714  0.09182
# 6172 2019-08-29 22:16:12.827206             0.54222  0.01604
# 6173 2019-08-29 22:16:18.044272             0.59810  0.02852
# 6174 2019-08-29 23:15:01.294752             0.56464  0.03174
# 6175 2019-08-29 23:08:30.382610             0.54276  0.01286
# 6176 2019-08-29 23:15:13.084512             0.65842  0.06562
# 6177 2019-08-29 23:15:18.896974             0.56868  0.02624
# 6178 2019-08-29 23:27:18.657687             0.64782  0.04570
# 6179 2019-08-29 23:32:39.092168             0.56572  0.02808
# 6180 2019-08-30 18:22:48.134472             0.87518  0.07850
# 6181 2019-08-30 18:22:38.722147             0.72922  0.07706
# 6182 2019-08-30 18:22:42.838908             1.27462  0.06340
# 6183                        NaT                 NaN      NaN
# 6184 2019-08-30 19:22:35.475419             0.62502  0.05244
# 6185 2019-08-30 19:22:36.840766             0.55378  0.01612
# 6186 2019-08-30 19:58:13.574994             0.62702  0.04606
# 6187 2019-08-30 20:17:35.898504             0.60432  0.01518
# 6188 2019-08-30 21:20:24.549898             0.91846  0.13134
# 6189 2019-08-30 21:20:32.912265             0.72988  0.03162
# 6190 2019-08-30 21:53:01.384686             0.80750  0.01296
# 6191 2019-08-30 21:31:59.183332             0.58820  0.01534
# 6192                        NaT                 NaN      NaN
# 6193 2019-08-30 21:52:42.852286             0.69996  0.05592
# 6194 2019-08-30 22:46:07.900525             0.60938  0.01754
#
#       fast_trough_v_long_square  upstroke_downstroke_ratio_long_square  \
# 0                    -57.843750                               2.197645
# 1                           NaN                                    NaN
# 2                    -42.156250                               3.670867
# 3                           NaN                                    NaN
# 4                    -55.000000                               1.611259
# 5                    -41.937500                               3.531583
# 6                    -62.312500                               1.869017
# 7                    -57.500000                               2.070813
# 8                           NaN                                    NaN
# 9                    -51.375000                               1.811722
# 10                   -54.937500                               2.030166
# 11                          NaN                                    NaN
# 12                   -52.750000                               2.515149
# 13                   -52.437500                               2.977473
# 14                   -56.281250                               3.422514
# 15                          NaN                                    NaN
# 16                   -48.281250                               1.475640
# 17                          NaN                                    NaN
# 18                   -31.500000                               3.600039
# 19                          NaN                                    NaN
# 20                          NaN                                    NaN
# 21                          NaN                                    NaN
# 22                   -49.406250                               1.699032
# 23                          NaN                                    NaN
# 24                          NaN                                    NaN
# 25                          NaN                                    NaN
# 26                          NaN                                    NaN
# 27                          NaN                                    NaN
# 28                   -42.281250                               2.683493
# 29                   -59.406250                               2.345498
# ...                         ...                                    ...
# 6165                 -40.424999                               4.694943
# 6166                 -38.375000                               5.863601
# 6167                 -46.456249                               3.968681
# 6168                 -44.231251                               4.261588
# 6169                 -42.762501                               3.205588
# 6170                 -50.424999                               2.893053
# 6171                 -48.474998                               5.300358
# 6172                 -45.562500                               3.097266
# 6173                 -33.424999                               2.603244
# 6174                 -45.656250                               3.173011
# 6175                 -49.068748                               3.600008
# 6176                 -52.681248                               4.574494
# 6177                 -46.493748                               3.088727
# 6178                 -44.162498                               2.663709
# 6179                 -46.099998                               2.833653
# 6180                 -31.168749                               4.459422
# 6181                 -44.700001                               5.305746
# 6182                 -62.418751                               4.327991
# 6183                        NaN                                    NaN
# 6184                 -36.793751                               3.556319
# 6185                 -60.706249                               1.906208
# 6186                 -58.137501                               1.230601
# 6187                 -62.674999                               1.569650
# 6188                 -42.000000                               4.635337
# 6189                 -47.224998                               2.492633
# 6190                 -48.899998                               2.943984
# 6191                 -50.456249                               3.736279
# 6192                        NaN                                    NaN
# 6193                 -49.393749                               3.924984
# 6194                 -47.862499                               3.826916
#
#       trough_v_ramp  peak_v_long_square  adaptation
# 0        -52.156250           26.500000    0.082358
# 1               NaN                 NaN         NaN
# 2        -47.343750           27.562500   -0.081838
# 3               NaN                 NaN         NaN
# 4        -49.859375           30.593750         NaN
# 5        -37.828125           31.062500    0.207067
# 6        -58.781250           11.437500         NaN
# 7        -61.687500           24.750000         NaN
# 8               NaN                 NaN         NaN
# 9        -50.343750           27.187500    0.051346
# 10       -49.328125           35.000000         NaN
# 11              NaN                 NaN         NaN
# 12       -50.906250           36.406250         NaN
# 13       -52.406250           24.062500    0.234685
# 14       -58.031250           33.281250    0.132528
# 15              NaN                 NaN         NaN
# 16       -44.500000           15.531250    0.004810
# 17              NaN                 NaN         NaN
# 18       -27.843750           45.656250         NaN
# 19              NaN                 NaN         NaN
# 20              NaN                 NaN         NaN
# 21              NaN                 NaN         NaN
# 22       -49.015625           17.000000    0.047227
# 23              NaN                 NaN         NaN
# 24              NaN                 NaN         NaN
# 25              NaN                 NaN         NaN
# 26              NaN                 NaN         NaN
# 27              NaN                 NaN         NaN
# 28       -44.593750           25.781250    0.025662
# 29       -59.671875           29.312500    0.017613
# ...             ...                 ...         ...
# 6165     -52.706249           47.656250    0.092663
# 6166     -46.514584           26.312500    0.077737
# 6167     -55.162502           43.118748    0.067060
# 6168     -47.820831           39.343750         NaN
# 6169     -49.588543           38.899998         NaN
# 6170     -53.464581           36.418751    0.076011
# 6171     -57.145832           44.424999    0.049728
# 6172     -51.302082           30.268749         NaN
# 6173     -36.450001           29.174999    0.199831
# 6174     -51.545834           43.612499    0.035424
# 6175     -51.206249           28.650000    0.131544
# 6176     -57.125000           40.506248    0.038797
# 6177     -50.875000           33.718750    0.039120
# 6178     -48.475002           31.931250    0.054645
# 6179     -49.270832           38.681248    0.117718
# 6180     -42.554165           41.181248    0.013620
# 6181     -55.418747           53.974998    0.036741
# 6182     -55.784996           19.956249    0.010509
# 6183            NaN                 NaN         NaN
# 6184     -49.491669           42.968750    0.108429
# 6185     -58.495834           34.881248         NaN
# 6186     -58.504688           24.400000    0.006729
# 6187     -63.493748           28.362499    0.003019
# 6188     -44.658337           46.406250    0.041341
# 6189     -47.664581           32.006248    0.071613
# 6190     -49.064064           39.200001    0.065083
# 6191     -55.379166           36.006248    0.118549
# 6192            NaN                 NaN         NaN
# 6193     -52.291668           30.331249   -0.001153
# 6194     -51.356251           41.556248    0.154987
#
# [6195 rows x 56 columns]

# %%
q = """
SELECT cell.name,
cell.id,
ef.*
FROM specimens cell 
JOIN ephys_roi_results err ON cell.ephys_roi_result_id = err.id
JOIN projects proj ON cell.project_id = proj.id
LEFT JOIN ephys_features ef on ef.specimen_id = cell.id
AND proj.code in ('mIVSCC-MET')"""

lims_df = get_lims_dataframe(q)
lims_df
# Out:
#              tau  upstroke_downstroke_ratio_short_square  thumbnail_sweep_id  \
# 0      46.068612                                1.629215         809630410.0
# 1       6.309486                                1.411009         809638950.0
# 2       6.390954                                1.622022         818810664.0
# 3      87.041986                                1.576874         869520640.0
# 4       7.247627                                1.458550         821532548.0
# 5      20.677347                                2.976289         696994967.0
# 6      33.214118                                4.251538         696995208.0
# 7      12.288935                                1.435377         830394112.0
# 8      25.324462                                1.792097         804848289.0
# 9      16.676097                                3.478696         697012899.0
# 10     12.448599                                1.443988         861033593.0
# 11     16.650169                                3.169951         697089494.0
# 12     19.499030                                4.362271         697089610.0
# 13     21.772884                                5.102300         697231640.0
# 14     20.917890                                2.427577         697232000.0
# 15     44.063178                                4.058335         697294711.0
# 16      9.599761                                1.720736         697294908.0
# 17     34.368614                                1.777251         804929147.0
# 18      8.606057                                3.946493         910914512.0
# 19     10.626420                                1.757002         831000801.0
# 20      9.621258                                1.428522         861035933.0
# 21      6.914309                                1.831693         861037429.0
# 22     15.500281                                2.517841         861163050.0
# 23      6.903475                                1.479473         861207324.0
# 24      7.325924                                1.544403         861245619.0
# 25      9.847603                                1.128998         875270832.0
# 26     21.927578                                3.443090         905313340.0
# 27      8.018489                                1.305058         905347408.0
# 28     56.210070                                1.744230         804828237.0
# 29     14.371974                                1.611539         804847272.0
# ...          ...                                     ...                 ...
# 25252        NaN                                     NaN                 NaN
# 25253        NaN                                     NaN                 NaN
# 25254        NaN                                     NaN                 NaN
# 25255        NaN                                     NaN                 NaN
# 25256        NaN                                     NaN                 NaN
# 25257        NaN                                     NaN                 NaN
# 25258        NaN                                     NaN                 NaN
# 25259        NaN                                     NaN                 NaN
# 25260        NaN                                     NaN                 NaN
# 25261        NaN                                     NaN                 NaN
# 25262        NaN                                     NaN                 NaN
# 25263        NaN                                     NaN                 NaN
# 25264        NaN                                     NaN                 NaN
# 25265        NaN                                     NaN                 NaN
# 25266        NaN                                     NaN                 NaN
# 25267        NaN                                     NaN                 NaN
# 25268        NaN                                     NaN                 NaN
# 25269        NaN                                     NaN                 NaN
# 25270        NaN                                     NaN                 NaN
# 25271        NaN                                     NaN                 NaN
# 25272        NaN                                     NaN                 NaN
# 25273        NaN                                     NaN                 NaN
# 25274        NaN                                     NaN                 NaN
# 25275        NaN                                     NaN                 NaN
# 25276        NaN                                     NaN                 NaN
# 25277        NaN                                     NaN                 NaN
# 25278        NaN                                     NaN                 NaN
# 25279        NaN                                     NaN                 NaN
# 25280        NaN                                     NaN                 NaN
# 25281        NaN                                     NaN                 NaN
#
#       has_delay  threshold_v_ramp  peak_v_short_square  \
# 0          None               NaN            16.793180
# 1          None               NaN            25.327499
# 2          None               NaN            19.479687
# 3          None               NaN             3.412500
# 4          None               NaN            21.600000
# 5         False        -33.656253            41.085940
# 6         False        -44.520836            48.117189
# 7          None               NaN            21.559376
# 8          None        -29.112497            12.025000
# 9         False        -35.989585            34.806252
# 10         None               NaN            24.921875
# 11        False        -43.604168            42.993752
# 12        False        -39.625003            47.661460
# 13        False        -33.677087            54.195315
# 14        False        -42.947917            24.718752
# 15        False        -42.203125            34.268752
# 16        False        -43.458335            20.506250
# 17         None               NaN           -26.724998
# 18         None        -36.252079            44.406250
# 19         None               NaN            26.318748
# 20         None               NaN            21.523438
# 21         None               NaN             7.812500
# 22         None               NaN            21.601562
# 23         None               NaN            20.804688
# 24         None               NaN            14.046875
# 25         None               NaN            26.421875
# 26         None               NaN            26.343750
# 27         None               NaN            26.322222
# 28         None        -19.299999            25.578125
# 29         None        -33.660416            36.112499
# ...         ...               ...                  ...
# 25252      None               NaN                  NaN
# 25253      None               NaN                  NaN
# 25254      None               NaN                  NaN
# 25255      None               NaN                  NaN
# 25256      None               NaN                  NaN
# 25257      None               NaN                  NaN
# 25258      None               NaN                  NaN
# 25259      None               NaN                  NaN
# 25260      None               NaN                  NaN
# 25261      None               NaN                  NaN
# 25262      None               NaN                  NaN
# 25263      None               NaN                  NaN
# 25264      None               NaN                  NaN
# 25265      None               NaN                  NaN
# 25266      None               NaN                  NaN
# 25267      None               NaN                  NaN
# 25268      None               NaN                  NaN
# 25269      None               NaN                  NaN
# 25270      None               NaN                  NaN
# 25271      None               NaN                  NaN
# 25272      None               NaN                  NaN
# 25273      None               NaN                  NaN
# 25274      None               NaN                  NaN
# 25275      None               NaN                  NaN
# 25276      None               NaN                  NaN
# 25277      None               NaN                  NaN
# 25278      None               NaN                  NaN
# 25279      None               NaN                  NaN
# 25280      None               NaN                  NaN
# 25281      None               NaN                  NaN
#
#        upstroke_downstroke_ratio_ramp       sag                 updated_at  \
# 0                                 NaN  0.047297 2019-01-17 19:12:40.217597
# 1                                 NaN  0.035610 2019-01-17 19:32:04.970144
# 2                                 NaN  0.055444 2019-02-06 00:26:25.252915
# 3                                 NaN  0.075305 2019-05-16 20:06:55.409414
# 4                                 NaN  0.011772 2019-02-12 18:57:44.583239
# 5                            2.797883  0.155472 2018-05-11 18:58:07.446023
# 6                            4.369519  0.170575 2018-05-11 18:57:59.839707
# 7                                 NaN  0.077684 2019-02-28 19:53:20.046030
# 8                            1.630815  0.087595 2019-01-07 19:54:43.737155
# 9                            3.959953  0.017999 2018-05-11 19:07:43.425874
# 10                                NaN  0.020838 2019-05-02 00:51:04.563336
# 11                           4.487137  0.068230 2018-05-11 19:58:13.529106
# 12                           5.045620  0.061909 2018-05-11 19:58:55.288286
# 13                           4.726119  0.025117 2018-05-11 21:19:12.814309
# 14                           2.959487  0.171654 2018-05-11 21:18:55.313658
# 15                           4.393369  0.273478 2018-05-11 22:07:48.468751
# 16                           1.621905  0.019345 2018-05-11 22:08:08.427818
# 17                                NaN  0.169751 2019-01-07 21:45:14.652810
# 18                           3.624523  0.007989 2019-07-23 18:45:28.326745
# 19                                NaN  0.039465 2019-03-01 20:14:01.752796
# 20                                NaN  0.015715 2019-05-02 00:51:06.413154
# 21                                NaN  0.012980 2019-05-02 00:53:27.285823
# 22                                NaN  0.218878 2019-05-02 01:32:22.367995
# 23                                NaN  0.026561 2019-05-02 01:45:06.352626
# 24                                NaN -0.003801 2019-05-02 01:55:01.672189
# 25                                NaN  0.176082 2019-05-24 20:11:00.931286
# 26                                NaN  0.081698 2019-07-13 03:04:07.979171
# 27                                NaN  0.107704 2019-07-13 03:10:40.077505
# 28                           0.810913  0.084297 2019-01-07 19:44:07.057503
# 29                           1.190578  0.098625 2019-01-07 19:54:29.636448
# ...                               ...       ...                        ...
# 25252                             NaN       NaN                        NaT
# 25253                             NaN       NaN                        NaT
# 25254                             NaN       NaN                        NaT
# 25255                             NaN       NaN                        NaT
# 25256                             NaN       NaN                        NaT
# 25257                             NaN       NaN                        NaT
# 25258                             NaN       NaN                        NaT
# 25259                             NaN       NaN                        NaT
# 25260                             NaN       NaN                        NaT
# 25261                             NaN       NaN                        NaT
# 25262                             NaN       NaN                        NaT
# 25263                             NaN       NaN                        NaT
# 25264                             NaN       NaN                        NaT
# 25265                             NaN       NaN                        NaT
# 25266                             NaN       NaN                        NaT
# 25267                             NaN       NaN                        NaT
# 25268                             NaN       NaN                        NaT
# 25269                             NaN       NaN                        NaT
# 25270                             NaN       NaN                        NaT
# 25271                             NaN       NaN                        NaT
# 25272                             NaN       NaN                        NaT
# 25273                             NaN       NaN                        NaT
# 25274                             NaN       NaN                        NaT
# 25275                             NaN       NaN                        NaT
# 25276                             NaN       NaN                        NaT
# 25277                             NaN       NaN                        NaT
# 25278                             NaN       NaN                        NaT
# 25279                             NaN       NaN                        NaT
# 25280                             NaN       NaN                        NaT
# 25281                             NaN       NaN                        NaT
#
#        threshold_t_ramp     ...      trough_v_short_square  f_i_curve_slope  \
# 0                   NaN     ...                 -58.533524     6.723404e-01
# 1                   NaN     ...                 -55.353752     6.100000e-01
# 2                   NaN     ...                 -54.535934     5.750000e-01
# 3                   NaN     ...                 -68.378128     9.099119e-19
# 4                   NaN     ...                 -59.375000     6.057692e-01
# 5              4.950100     ...                 -76.312504     1.889286e-01
# 6              1.658880     ...                 -67.515629     3.405457e-01
# 7                   NaN     ...                 -75.956253     1.769231e+00
# 8              3.277633     ...                 -69.012497     4.000000e-01
# 9              5.518340     ...                 -76.987503     1.388889e-01
# 10                  NaN     ...                 -71.703125     1.704098e+00
# 11             3.286480     ...                 -80.506253     2.724852e-01
# 12             3.703307     ...                 -77.005208     9.749672e-02
# 13             8.712333     ...                 -77.531252     6.217241e-02
# 14             3.531533     ...                 -73.587500     2.084735e-01
# 15             1.362000     ...                 -61.543753     2.334802e-01
# 16            12.341720     ...                 -79.587505     1.365779e-01
# 17                  NaN     ...                 -42.324997     2.500000e-02
# 18             9.310587     ...                 -75.674995     2.250000e-01
# 19                  NaN     ...                 -67.237503     6.750000e-01
# 20                  NaN     ...                 -60.921875     1.237500e+00
# 21                  NaN     ...                 -80.312500     3.597367e-18
# 22                  NaN     ...                 -60.898438     6.250000e-02
# 23                  NaN     ...                 -77.296875     8.042857e-01
# 24                  NaN     ...                 -74.828125     5.436047e-02
# 25                  NaN     ...                 -66.406250     1.352500e+00
# 26                  NaN     ...                 -66.156250     1.357143e-02
# 27                  NaN     ...                 -76.048615     7.181818e-01
# 28            12.349010     ...                 -68.762497     9.787234e-02
# 29             6.871647     ...                 -70.965622     1.350000e-01
# ...                 ...     ...                        ...              ...
# 25252               NaN     ...                        NaN              NaN
# 25253               NaN     ...                        NaN              NaN
# 25254               NaN     ...                        NaN              NaN
# 25255               NaN     ...                        NaN              NaN
# 25256               NaN     ...                        NaN              NaN
# 25257               NaN     ...                        NaN              NaN
# 25258               NaN     ...                        NaN              NaN
# 25259               NaN     ...                        NaN              NaN
# 25260               NaN     ...                        NaN              NaN
# 25261               NaN     ...                        NaN              NaN
# 25262               NaN     ...                        NaN              NaN
# 25263               NaN     ...                        NaN              NaN
# 25264               NaN     ...                        NaN              NaN
# 25265               NaN     ...                        NaN              NaN
# 25266               NaN     ...                        NaN              NaN
# 25267               NaN     ...                        NaN              NaN
# 25268               NaN     ...                        NaN              NaN
# 25269               NaN     ...                        NaN              NaN
# 25270               NaN     ...                        NaN              NaN
# 25271               NaN     ...                        NaN              NaN
# 25272               NaN     ...                        NaN              NaN
# 25273               NaN     ...                        NaN              NaN
# 25274               NaN     ...                        NaN              NaN
# 25275               NaN     ...                        NaN              NaN
# 25276               NaN     ...                        NaN              NaN
# 25277               NaN     ...                        NaN              NaN
# 25278               NaN     ...                        NaN              NaN
# 25279               NaN     ...                        NaN              NaN
# 25280               NaN     ...                        NaN              NaN
# 25281               NaN     ...                        NaN              NaN
#
#                       created_at  peak_t_long_square  latency  \
# 0     2019-01-17 19:12:40.217597             0.62088  0.04230
# 1     2019-01-17 19:32:04.970144             0.51534  0.00944
# 2     2019-02-06 00:26:25.252915             0.61070  0.07508
# 3     2019-05-16 20:06:55.409414             0.50710  0.00520
# 4     2019-02-12 18:57:44.583239             0.52204  0.01200
# 5     2018-05-11 18:58:07.446023             1.11784  0.03632
# 6     2018-05-11 18:57:59.839707             1.39190  0.02916
# 7     2019-02-28 19:53:20.046030             0.51590  0.00878
# 8     2019-01-07 19:54:43.737155             0.56440  0.02922
# 9     2018-05-11 19:07:43.425874             1.07450  0.02670
# 10    2019-05-02 00:51:04.563336             0.51446  0.00752
# 11    2018-05-11 19:58:13.529106             1.24546  0.07534
# 12    2018-05-11 19:58:55.288286             1.19652  0.05130
# 13    2018-05-11 21:19:12.814309             1.13936  0.06362
# 14    2018-05-11 21:18:55.313658             1.06936  0.01836
# 15    2018-05-11 22:07:48.468751             1.12052  0.01242
# 16    2018-05-11 22:08:08.427818             1.04860  0.01362
# 17    2019-01-07 21:45:14.652810             0.55918  0.02090
# 18    2019-07-23 18:45:28.326745             0.91544  0.07116
# 19    2019-03-01 20:14:01.752796             0.52340  0.01176
# 20    2019-05-02 00:51:06.413154             0.50630  0.00398
# 21    2019-05-02 00:53:27.285823             0.51696  0.00826
# 22    2019-05-02 01:32:22.367995             0.54502  0.01518
# 23    2019-05-02 01:45:06.352626             0.53086  0.01530
# 24    2019-05-02 01:55:01.672189             0.50836  0.00636
# 25    2019-05-24 20:11:00.931286             0.51594  0.00796
# 26    2019-07-13 03:04:07.979171             0.54122  0.01486
# 27    2019-07-13 03:10:40.077505             0.51658  0.01046
# 28    2019-01-07 19:44:07.057503             0.54770  0.02064
# 29    2019-01-07 19:54:29.636448             0.57926  0.02198
# ...                          ...                 ...      ...
# 25252                        NaT                 NaN      NaN
# 25253                        NaT                 NaN      NaN
# 25254                        NaT                 NaN      NaN
# 25255                        NaT                 NaN      NaN
# 25256                        NaT                 NaN      NaN
# 25257                        NaT                 NaN      NaN
# 25258                        NaT                 NaN      NaN
# 25259                        NaT                 NaN      NaN
# 25260                        NaT                 NaN      NaN
# 25261                        NaT                 NaN      NaN
# 25262                        NaT                 NaN      NaN
# 25263                        NaT                 NaN      NaN
# 25264                        NaT                 NaN      NaN
# 25265                        NaT                 NaN      NaN
# 25266                        NaT                 NaN      NaN
# 25267                        NaT                 NaN      NaN
# 25268                        NaT                 NaN      NaN
# 25269                        NaT                 NaN      NaN
# 25270                        NaT                 NaN      NaN
# 25271                        NaT                 NaN      NaN
# 25272                        NaT                 NaN      NaN
# 25273                        NaT                 NaN      NaN
# 25274                        NaT                 NaN      NaN
# 25275                        NaT                 NaN      NaN
# 25276                        NaT                 NaN      NaN
# 25277                        NaT                 NaN      NaN
# 25278                        NaT                 NaN      NaN
# 25279                        NaT                 NaN      NaN
# 25280                        NaT                 NaN      NaN
# 25281                        NaT                 NaN      NaN
#
#        fast_trough_v_long_square  upstroke_downstroke_ratio_long_square  \
# 0                     -48.656250                               1.531230
# 1                     -54.418751                               1.421988
# 2                     -47.081249                               1.612776
# 3                     -57.899998                               1.550681
# 4                     -51.931248                               1.480023
# 5                     -46.937504                               2.917276
# 6                     -51.281250                               4.262800
# 7                     -59.899998                               1.383077
# 8                     -50.612499                               1.911140
# 9                     -47.781250                               3.939144
# 10                    -58.000000                               1.396224
# 11                    -56.187504                               3.854387
# 12                    -47.093754                               5.238919
# 13                    -41.562500                               4.975590
# 14                    -55.093754                               2.764632
# 15                    -49.437500                               4.418098
# 16                    -69.406258                               1.713358
# 17                    -44.912498                               2.094747
# 18                    -44.681248                               4.017615
# 19                    -51.587498                               1.645860
# 20                    -54.218750                               1.289724
# 21                    -60.468750                               1.537575
# 22                    -46.406250                               2.311836
# 23                    -61.437500                               1.368671
# 24                    -61.843750                               1.602363
# 25                    -61.187500                               1.101228
# 26                    -50.343750                               3.213307
# 27                    -59.962498                               1.169551
# 28                    -46.387501                               1.743491
# 29                    -58.643749                               1.585487
# ...                          ...                                    ...
# 25252                        NaN                                    NaN
# 25253                        NaN                                    NaN
# 25254                        NaN                                    NaN
# 25255                        NaN                                    NaN
# 25256                        NaN                                    NaN
# 25257                        NaN                                    NaN
# 25258                        NaN                                    NaN
# 25259                        NaN                                    NaN
# 25260                        NaN                                    NaN
# 25261                        NaN                                    NaN
# 25262                        NaN                                    NaN
# 25263                        NaN                                    NaN
# 25264                        NaN                                    NaN
# 25265                        NaN                                    NaN
# 25266                        NaN                                    NaN
# 25267                        NaN                                    NaN
# 25268                        NaN                                    NaN
# 25269                        NaN                                    NaN
# 25270                        NaN                                    NaN
# 25271                        NaN                                    NaN
# 25272                        NaN                                    NaN
# 25273                        NaN                                    NaN
# 25274                        NaN                                    NaN
# 25275                        NaN                                    NaN
# 25276                        NaN                                    NaN
# 25277                        NaN                                    NaN
# 25278                        NaN                                    NaN
# 25279                        NaN                                    NaN
# 25280                        NaN                                    NaN
# 25281                        NaN                                    NaN
#
#        trough_v_ramp  peak_v_long_square  adaptation
# 0                NaN           14.718750    0.007492
# 1                NaN           27.456249    0.023410
# 2                NaN           16.262499    0.053562
# 3                NaN            5.356250         NaN
# 4                NaN           20.287500    0.002700
# 5         -51.604168           39.125004    0.037970
# 6         -51.531251           48.343750    0.043399
# 7                NaN           19.531250    0.001766
# 8         -48.020832           17.231249    0.023762
# 9         -52.322918           32.000000         NaN
# 10               NaN           23.437500    0.000353
# 11        -56.114587           44.093750    0.012902
# 12        -55.270836           47.125000    0.252986
# 13        -51.406254           53.187500         NaN
# 14        -56.197918           10.500001    0.037763
# 15        -49.578129           34.531250    0.042904
# 16        -63.875003           16.000000         NaN
# 17               NaN           31.812500         NaN
# 18        -48.693752           41.837498    0.029034
# 19               NaN           25.412500    0.005864
# 20               NaN           19.687500   -0.000139
# 21               NaN            7.093750         NaN
# 22               NaN           14.593750    0.102675
# 23               NaN           12.250000    0.005517
# 24               NaN           14.625000         NaN
# 25               NaN           24.843750    0.000626
# 26               NaN           14.343750    0.031236
# 27               NaN           19.481249    0.008452
# 28        -52.853127           27.906250    0.374929
# 29        -50.437500           36.212498    0.078258
# ...              ...                 ...         ...
# 25252            NaN                 NaN         NaN
# 25253            NaN                 NaN         NaN
# 25254            NaN                 NaN         NaN
# 25255            NaN                 NaN         NaN
# 25256            NaN                 NaN         NaN
# 25257            NaN                 NaN         NaN
# 25258            NaN                 NaN         NaN
# 25259            NaN                 NaN         NaN
# 25260            NaN                 NaN         NaN
# 25261            NaN                 NaN         NaN
# 25262            NaN                 NaN         NaN
# 25263            NaN                 NaN         NaN
# 25264            NaN                 NaN         NaN
# 25265            NaN                 NaN         NaN
# 25266            NaN                 NaN         NaN
# 25267            NaN                 NaN         NaN
# 25268            NaN                 NaN         NaN
# 25269            NaN                 NaN         NaN
# 25270            NaN                 NaN         NaN
# 25271            NaN                 NaN         NaN
# 25272            NaN                 NaN         NaN
# 25273            NaN                 NaN         NaN
# 25274            NaN                 NaN         NaN
# 25275            NaN                 NaN         NaN
# 25276            NaN                 NaN         NaN
# 25277            NaN                 NaN         NaN
# 25278            NaN                 NaN         NaN
# 25279            NaN                 NaN         NaN
# 25280            NaN                 NaN         NaN
# 25281            NaN                 NaN         NaN
#
# [25282 rows x 55 columns]

# %%
lims_df.columns
# Out:
# Index([u'tau', u'upstroke_downstroke_ratio_short_square',
#        u'thumbnail_sweep_id', u'has_delay', u'threshold_v_ramp',
#        u'peak_v_short_square', u'upstroke_downstroke_ratio_ramp', u'sag',
#        u'updated_at', u'threshold_t_ramp', u'slow_trough_v_ramp', u'vrest',
#        u'has_pause', u'trough_t_ramp', u'trough_v_long_square',
#        u'threshold_t_short_square', u'id', u'trough_t_short_square',
#        u'fast_trough_v_ramp', u'trough_t_long_square',
#        u'slow_trough_v_long_square', u'rheobase_sweep_id', u'peak_t_ramp',
#        u'has_burst', u'slow_trough_t_long_square', u'threshold_v_long_square',
#        u'fast_trough_t_long_square', u'ri', u'threshold_t_long_square',
#        u'threshold_v_short_square', u'avg_isi', u'vm_for_sag', u'specimen_id',
#        u'threshold_i_long_square', u'threshold_i_short_square',
#        u'slow_trough_t_ramp', u'peak_v_ramp', u'fast_trough_v_short_square',
#        u'fast_trough_t_short_square', u'fast_trough_t_ramp',
#        u'slow_trough_t_short_square', u'threshold_i_ramp',
#        u'slow_trough_v_short_square', u'peak_t_short_square', u'name',
#        u'trough_v_short_square', u'f_i_curve_slope', u'created_at',
#        u'peak_t_long_square', u'latency', u'fast_trough_v_long_square',
#        u'upstroke_downstroke_ratio_long_square', u'trough_v_ramp',
#        u'peak_v_long_square', u'adaptation'],
#       dtype='object')

# %% [markdown]
# # Obtain mapping data from shiny, stored on the network

# %%
shiny_df = pd.read_csv("\\\\allen\\programs\\celltypes\\workgroups\\279\\IVSCC_KPIs\\\shiny_LIMS.csv")
shiny_df
# Out:
#       specimen_id                                        cell_name  \
# 0       639568687                Oxtr-T2A-Cre;Ai14-351467.05.02.01
# 1       639568972                Oxtr-T2A-Cre;Ai14-351467.03.01.01
# 2       639604957                Oxtr-T2A-Cre;Ai14-351467.05.02.02
# 3       639615709  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-350934.04.01.01
# 4       639622744                Oxtr-T2A-Cre;Ai14-351467.05.02.03
# 5       639636584  Nos1-CreERT2;Sst-IRES-FlpO;Ai65-350934.04.01.02
# 6       639671955               Gad2-IRES-Cre;Ai14-350672.06.02.01
# 7       639674270             Chrna2-Cre_OE25;Ai14-351067.04.02.01
# 8       639689311             Chrna2-Cre_OE25;Ai14-351067.04.02.02
# 9       639689999               Gad2-IRES-Cre;Ai14-350672.03.01.01
# 10      639695961             Chrna2-Cre_OE25;Ai14-351067.04.01.01
# 11      639701690             Chrna2-Cre_OE25;Ai14-351067.04.01.02
# 12      639706236               Gad2-IRES-Cre;Ai14-350672.04.01.01
# 13      639708328             Chrna2-Cre_OE25;Ai14-351067.03.02.01
# 14      639708371               Gad2-IRES-Cre;Ai14-350672.04.01.02
# 15      639715846             Chrna2-Cre_OE25;Ai14-351067.04.01.03
# 16      639719157             Chrna2-Cre_OE25;Ai14-351067.03.02.02
# 17      639715810               Gad2-IRES-Cre;Ai14-350672.04.01.03
# 18      639719034               Gad2-IRES-Cre;Ai14-350672.04.01.04
# 19      639725628             Chrna2-Cre_OE25;Ai14-351067.04.01.04
# 20      639796648               Gad2-IRES-Cre;Ai14-350674.04.01.01
# 21      639797308               Gad2-IRES-Cre;Ai14-350674.04.02.01
# 22      639797005               Gad2-IRES-Cre;Ai14-350674.04.01.02
# 23      639798164               Gad2-IRES-Cre;Ai14-350674.04.01.03
# 24      639798922               Gad2-IRES-Cre;Ai14-350674.04.02.02
# 25      639809296               Gad2-IRES-Cre;Ai14-350674.03.01.01
# 26      639808649               Gad2-IRES-Cre;Ai14-350674.06.02.01
# 27      639809582             Chrna2-Cre_OE25;Ai14-351070.03.01.01
# 28      639818314             Chrna2-Cre_OE25;Ai14-351070.03.01.02
# 29      639818525               Gad2-IRES-Cre;Ai14-350674.03.01.02
# ...           ...                                              ...
# 9813    847865431                        H19.06.352.99.01.05.01.03
# 9814    847865702                              H19.29.146.11.24.04
# 9815    847865964                              H19.29.146.11.24.05
# 9816    847866634                              H19.29.146.11.41.01
# 9817    847866956                              H19.29.146.11.41.03
# 9818    847867445                              H19.29.146.11.42.04
# 9819    847867601                              H19.29.146.11.42.05
# 9820    847870147                              H19.29.147.11.41.01
# 9821    847870428            Slc17a6-IRES-Cre;Ai14-454538.04.01.02
# 9822    847870440                              H19.29.147.11.42.03
# 9823    847870571                              H19.29.147.11.42.04
# 9824    847875155                        H19.06.352.99.01.05.01.04
# 9825    847876759            Slc17a6-IRES-Cre;Ai14-454538.04.01.03
# 9826    847880487            Slc17a6-IRES-Cre;Ai14-454538.05.02.01
# 9827    847887193            Slc17a6-IRES-Cre;Ai14-454538.04.02.01
# 9828    847895867                        H19.06.352.99.01.05.01.06
# 9829    847898754            Slc17a6-IRES-Cre;Ai14-454538.04.02.02
# 9830    847902873            Slc17a6-IRES-Cre;Ai14-454538.05.02.02
# 9831    847908829                        H19.06.352.99.01.05.01.07
# 9832    847931053                        H19.06.352.99.01.05.01.08
# 9833    847940517                        H19.06.352.99.01.05.01.09
# 9834    847946572                        H19.06.352.99.01.05.01.10
# 9835    847970074                        H19.06.352.99.01.05.01.11
# 9836    848278944                Sst-IRES-Cre;Ai14-454978.03.01.01
# 9837    848279397                Sst-IRES-Cre;Ai14-454978.04.02.01
# 9838    848303073                Sst-IRES-Cre;Ai14-454978.05.02.01
# 9839    848303383                Sst-IRES-Cre;Ai14-454978.03.01.02
# 9840    848334195                Sst-IRES-Cre;Ai14-454978.05.02.02
# 9841    848334636                Sst-IRES-Cre;Ai14-454978.03.01.03
# 9842    848348663                        H19.06.352.99.01.06.01.01
#
#      patched_cell_container rig_operator project_code  image_series_20x_id  \
# 0       P8S4_171002_351_A01           P8   mIVSCC-MET          643497668.0
# 1       P9S4_171002_401_A01           P9   mIVSCC-MET          643497439.0
# 2       P8S4_171002_352_A01           P8   mIVSCC-MET          643497668.0
# 3       P2S4_171002_051_A01           P2   mIVSCC-MET          643497697.0
# 4       P8S4_171002_353_A01           P8   mIVSCC-MET          643497668.0
# 5       P2S4_171002_052_A01           P2   mIVSCC-MET          643497697.0
# 6       PAS4_171002_451_A01           PA   mIVSCC-MET          643497953.0
# 7       P8S4_171002_354_A01           P8   mIVSCC-MET          643498140.0
# 8       P8S4_171002_355_A01           P8   mIVSCC-MET          643498140.0
# 9       P9S4_171002_402_A01           P9   mIVSCC-MET          643498169.0
# 10      P2S4_171002_053_A01           P2   mIVSCC-MET          643498237.0
# 11      P2S4_171002_054_A01           P2   mIVSCC-MET          643498237.0
# 12      P9S4_171002_403_A01           P9   mIVSCC-MET          643498191.0
# 13      P8S4_171002_356_A01           P8   mIVSCC-MET          643498214.0
# 14      P9S4_171002_404_A01           P9   mIVSCC-MET          643498191.0
# 15      P2S4_171002_055_A01           P2   mIVSCC-MET          643498237.0
# 16      P8S4_171002_357_A01           P8   mIVSCC-MET          643498214.0
# 17      P9S4_171002_405_A01           P9   mIVSCC-MET          643498191.0
# 18      P9S4_171002_406_A01           P9   mIVSCC-MET          643498191.0
# 19      P2S4_171002_056_A01           P2   mIVSCC-MET          643498237.0
# 20      P9S4_171003_401_A01           P9   mIVSCC-MET          643498263.0
# 21      P8S4_171003_351_A01           P8   mIVSCC-MET          643498317.0
# 22      P9S4_171003_402_A01           P9   mIVSCC-MET          643498263.0
# 23      P9S4_171003_403_A01           P9   mIVSCC-MET          643498263.0
# 24      P8S4_171003_352_A01           P8   mIVSCC-MET          643498317.0
# 25      PBS4_171003_501_A01           PB   mIVSCC-MET          643498768.0
# 26      PAS4_171003_451_A01           PA   mIVSCC-MET          643498599.0
# 27      P9S4_171003_404_A01           P9   mIVSCC-MET          643498718.0
# 28      P9S4_171003_405_A01           P9   mIVSCC-MET          643498718.0
# 29      PBS4_171003_502_A01           PB   mIVSCC-MET          643498768.0
# ...                     ...          ...          ...                  ...
# 9813    PXS4_190408_353_A01           PX  hIVSCC-METc          855190831.0
# 9814    PHS4_190321_204_A01           PH  hIVSCC-METx          952860636.0
# 9815    PHS4_190321_205_A01           PH  hIVSCC-METx          952860636.0
# 9816    PHS4_190321_401_A01           PH  hIVSCC-METx                  NaN
# 9817    PHS4_190321_402_A01           PH  hIVSCC-METx                  NaN
# 9818    PHS4_190321_403_A01           PH  hIVSCC-METx                  NaN
# 9819    PHS4_190321_404_A01           PH  hIVSCC-METx                  NaN
# 9820    PHS4_190402_401_A01           PH  hIVSCC-METx                  NaN
# 9821    P1S4_190408_005_A01           P1   mIVSCC-MET          855179940.0
# 9822    PHS4_190402_402_A01           PH  hIVSCC-METx          952862008.0
# 9823    PHS4_190402_403_A01           PH  hIVSCC-METx          952862008.0
# 9824    PXS4_190408_354_A01           PX  hIVSCC-METc          855190831.0
# 9825    P1S4_190408_006_A01           P1   mIVSCC-MET          855179940.0
# 9826    PAS4_190408_454_A01           PA   mIVSCC-MET          855180904.0
# 9827    PFS4_190408_704_A01           PF   mIVSCC-MET          855180358.0
# 9828    PXS4_190408_355_A01           PX  hIVSCC-METc          855190831.0
# 9829    PFS4_190408_705_A01           PF   mIVSCC-MET          855180358.0
# 9830    PAS4_190408_455_A01           PA   mIVSCC-MET          855180904.0
# 9831    PXS4_190408_356_A01           PX  hIVSCC-METc          855190831.0
# 9832    PXS4_190408_357_A01           PX  hIVSCC-METc          855190831.0
# 9833    PXS4_190408_358_A01           PX  hIVSCC-METc          855190831.0
# 9834    PXS4_190408_359_A01           PX  hIVSCC-METc          855190831.0
# 9835    PXS4_190408_360_A01           PX  hIVSCC-METc          855190831.0
# 9836    P1S4_190409_001_A01           P1   mIVSCC-MET          855181309.0
# 9837    PFS4_190409_701_A01           PF   mIVSCC-MET          855181130.0
# 9838    PAS4_190409_451_A01           PA   mIVSCC-MET          855181216.0
# 9839    P1S4_190409_002_A01           P1   mIVSCC-MET          855181309.0
# 9840    PAS4_190409_452_A01           PA   mIVSCC-MET          855181216.0
# 9841    P1S4_190409_003_A01           P1   mIVSCC-MET          855181309.0
# 9842    PXS4_190409_351_A01           PX  hIVSCC-METc          855191260.0
#
#      case_number recording_date        creation_date  \
# 0         351467     2017-10-02  2017-10-02-19-20-00
# 1         351467     2017-10-02  2017-10-02-19-20-13
# 2         351467     2017-10-02  2017-10-02-19-49-34
# 3         350934     2017-10-02  2017-10-02-20-04-24
# 4         351467     2017-10-02  2017-10-02-20-14-30
# 5         350934     2017-10-02  2017-10-02-20-39-54
# 6         350672     2017-10-02  2017-10-02-22-04-50
# 7         351067     2017-10-02  2017-10-02-22-14-43
# 8         351067     2017-10-02  2017-10-02-22-49-37
# 9         350672     2017-10-02  2017-10-02-22-49-50
# 10        351067     2017-10-02  2017-10-02-22-59-57
# 11        351067     2017-10-02  2017-10-02-23-19-25
# 12        350672     2017-10-02  2017-10-02-23-25-20
# 13        351067     2017-10-02  2017-10-02-23-35-07
# 14        350672     2017-10-02  2017-10-02-23-35-20
# 15        351067     2017-10-02  2017-10-02-23-49-41
# 16        351067     2017-10-02  2017-10-03-00-05-11
# 17        350672     2017-10-02  2017-10-02-23-49-30
# 18        350672     2017-10-02  2017-10-03-00-05-00
# 19        351067     2017-10-02  2017-10-03-00-29-59
# 20        350674     2017-10-03  2017-10-03-17-39-36
# 21        350674     2017-10-03  2017-10-03-18-04-27
# 22        350674     2017-10-03  2017-10-03-17-54-59
# 23        350674     2017-10-03  2017-10-03-18-14-09
# 24        350674     2017-10-03  2017-10-03-18-29-57
# 25        350674     2017-10-03  2017-10-03-18-54-11
# 26        350674     2017-10-03  2017-10-03-18-49-40
# 27        351070     2017-10-03  2017-10-03-18-54-22
# 28        351070     2017-10-03  2017-10-03-19-14-45
# 29        350674     2017-10-03  2017-10-03-19-14-57
# ...          ...            ...                  ...
# 9813  H19.06.352            NaN  2019-04-08-22-15-55
# 9814  H19.29.146            NaN                  NaN
# 9815  H19.29.146            NaN                  NaN
# 9816  H19.29.146            NaN                  NaN
# 9817  H19.29.146            NaN                  NaN
# 9818  H19.29.146            NaN                  NaN
# 9819  H19.29.146            NaN                  NaN
# 9820  H19.29.147            NaN                  NaN
# 9821      454538            NaN  2019-04-08-22-30-56
# 9822  H19.29.147            NaN                  NaN
# 9823  H19.29.147            NaN                  NaN
# 9824  H19.06.352            NaN  2019-04-08-22-45-55
# 9825      454538            NaN  2019-04-08-22-50-56
# 9826      454538            NaN  2019-04-08-23-00-54
# 9827      454538            NaN  2019-04-08-23-05-57
# 9828  H19.06.352            NaN  2019-04-08-23-26-01
# 9829      454538            NaN  2019-04-08-23-31-00
# 9830      454538            NaN  2019-04-08-23-40-56
# 9831  H19.06.352            NaN  2019-04-08-23-51-00
# 9832  H19.06.352            NaN  2019-04-09-00-25-57
# 9833  H19.06.352            NaN  2019-04-09-01-01-01
# 9834  H19.06.352            NaN  2019-04-09-01-20-55
# 9835  H19.06.352            NaN  2019-04-09-01-50-59
# 9836      454978            NaN  2019-04-09-18-25-59
# 9837      454978            NaN  2019-04-09-18-26-08
# 9838      454978            NaN  2019-04-09-18-40-51
# 9839      454978            NaN  2019-04-09-18-40-57
# 9840      454978            NaN  2019-04-09-19-00-50
# 9841      454978            NaN  2019-04-09-19-00-55
# 9842  H19.06.352            NaN  2019-04-09-19-11-00
#
#                                   donor_name        ...         \
# 0                   Oxtr-T2A-Cre;Ai14-351467        ...
# 1                   Oxtr-T2A-Cre;Ai14-351467        ...
# 2                   Oxtr-T2A-Cre;Ai14-351467        ...
# 3     Nos1-CreERT2;Sst-IRES-FlpO;Ai65-350934        ...
# 4                   Oxtr-T2A-Cre;Ai14-351467        ...
# 5     Nos1-CreERT2;Sst-IRES-FlpO;Ai65-350934        ...
# 6                  Gad2-IRES-Cre;Ai14-350672        ...
# 7                Chrna2-Cre_OE25;Ai14-351067        ...
# 8                Chrna2-Cre_OE25;Ai14-351067        ...
# 9                  Gad2-IRES-Cre;Ai14-350672        ...
# 10               Chrna2-Cre_OE25;Ai14-351067        ...
# 11               Chrna2-Cre_OE25;Ai14-351067        ...
# 12                 Gad2-IRES-Cre;Ai14-350672        ...
# 13               Chrna2-Cre_OE25;Ai14-351067        ...
# 14                 Gad2-IRES-Cre;Ai14-350672        ...
# 15               Chrna2-Cre_OE25;Ai14-351067        ...
# 16               Chrna2-Cre_OE25;Ai14-351067        ...
# 17                 Gad2-IRES-Cre;Ai14-350672        ...
# 18                 Gad2-IRES-Cre;Ai14-350672        ...
# 19               Chrna2-Cre_OE25;Ai14-351067        ...
# 20                 Gad2-IRES-Cre;Ai14-350674        ...
# 21                 Gad2-IRES-Cre;Ai14-350674        ...
# 22                 Gad2-IRES-Cre;Ai14-350674        ...
# 23                 Gad2-IRES-Cre;Ai14-350674        ...
# 24                 Gad2-IRES-Cre;Ai14-350674        ...
# 25                 Gad2-IRES-Cre;Ai14-350674        ...
# 26                 Gad2-IRES-Cre;Ai14-350674        ...
# 27               Chrna2-Cre_OE25;Ai14-351070        ...
# 28               Chrna2-Cre_OE25;Ai14-351070        ...
# 29                 Gad2-IRES-Cre;Ai14-350674        ...
# ...                                      ...        ...
# 9813                              H19.06.352        ...
# 9814                              H19.29.146        ...
# 9815                              H19.29.146        ...
# 9816                              H19.29.146        ...
# 9817                              H19.29.146        ...
# 9818                              H19.29.146        ...
# 9819                              H19.29.146        ...
# 9820                              H19.29.147        ...
# 9821            Slc17a6-IRES-Cre;Ai14-454538        ...
# 9822                              H19.29.147        ...
# 9823                              H19.29.147        ...
# 9824                              H19.06.352        ...
# 9825            Slc17a6-IRES-Cre;Ai14-454538        ...
# 9826            Slc17a6-IRES-Cre;Ai14-454538        ...
# 9827            Slc17a6-IRES-Cre;Ai14-454538        ...
# 9828                              H19.06.352        ...
# 9829            Slc17a6-IRES-Cre;Ai14-454538        ...
# 9830            Slc17a6-IRES-Cre;Ai14-454538        ...
# 9831                              H19.06.352        ...
# 9832                              H19.06.352        ...
# 9833                              H19.06.352        ...
# 9834                              H19.06.352        ...
# 9835                              H19.06.352        ...
# 9836                Sst-IRES-Cre;Ai14-454978        ...
# 9837                Sst-IRES-Cre;Ai14-454978        ...
# 9838                Sst-IRES-Cre;Ai14-454978        ...
# 9839                Sst-IRES-Cre;Ai14-454978        ...
# 9840                Sst-IRES-Cre;Ai14-454978        ...
# 9841                Sst-IRES-Cre;Ai14-454978        ...
# 9842                              H19.06.352        ...
#
#       batch_vendor_name broad_class_label            cluster_detail  \
# 0               RSC-125         GABAergic                     n_Sst
# 1               RSC-125         GABAergic                     n_Sst
# 2               RSC-125     Glutamatergic                        n3
# 3               RSC-125     Glutamatergic                Excitatory
# 4               RSC-125     Glutamatergic                Excitatory
# 5               RSC-125     Glutamatergic          L4 IT VISp Rspo1
# 6               RSC-125         GABAergic                Inhibitory
# 7               RSC-125         GABAergic          Vip Lmo1 Fam159b
# 8               RSC-125         GABAergic                     n_Sst
# 9               RSC-125         GABAergic                Lamp5 Lsp1
# 10              RSC-125         GABAergic                        n3
# 11              RSC-125         GABAergic                Inhibitory
# 12              RSC-125         GABAergic                        n4
# 13              RSC-125         GABAergic                  Sst Esm1
# 14              RSC-125         GABAergic                        n3
# 15              RSC-125         GABAergic             Vip Lmo1 Myl1
# 16              RSC-125         GABAergic               n_Sst_Pvalb
# 17              RSC-125         GABAergic                        n3
# 18              RSC-125     Glutamatergic                        n4
# 19              RSC-125     Glutamatergic                   n_L5_IT
# 20              RSC-125         GABAergic                Lamp5 Lsp1
# 21              RSC-125         GABAergic                Pvalb Tpbg
# 22              RSC-125         GABAergic                Inhibitory
# 23              RSC-125         GABAergic                     n_Sst
# 24              RSC-125         GABAergic                Inhibitory
# 25              RSC-125     Glutamatergic             n_L5_PT_Cdh13
# 26              RSC-125         GABAergic          n_Vip_Lamp5_Sncg
# 27              RSC-125         GABAergic                     n_Sst
# 28              RSC-125     Glutamatergic                   n_L5_IT
# 29              RSC-125         GABAergic                Inhibitory
# ...                 ...               ...                       ...
# 9813            RSC-207  GABAergic neuron                       NaN
# 9814            RSC-207  GABAergic neuron                       NaN
# 9815            RSC-207  GABAergic neuron                       NaN
# 9816            RSC-207  GABAergic neuron                       NaN
# 9817            RSC-207  GABAergic neuron                       NaN
# 9818            RSC-207  GABAergic neuron                       NaN
# 9819                NaN               NaN                       NaN
# 9820            RSC-207  GABAergic neuron                       NaN
# 9821            RSC-206     Glutamatergic  L5 IT VISp Hsd11b1 Endou
# 9822            RSC-207  GABAergic neuron                       NaN
# 9823            RSC-207  GABAergic neuron                       NaN
# 9824            RSC-207  GABAergic neuron                       NaN
# 9825            RSC-206     Glutamatergic                 n_L2/3_IT
# 9826            RSC-206     Glutamatergic                   n_L5_IT
# 9827            RSC-206     Glutamatergic   L6 IT VISp Penk Col27a1
# 9828            RSC-207  GABAergic neuron                       NaN
# 9829            RSC-206     Glutamatergic      L6 CT VISp Krt80 Sla
# 9830            RSC-206     Glutamatergic                   n_L5_IT
# 9831            RSC-207  GABAergic neuron                       NaN
# 9832            RSC-207  GABAergic neuron                       NaN
# 9833            RSC-207  GABAergic neuron                       NaN
# 9834            RSC-207  GABAergic neuron                       NaN
# 9835            RSC-207  GABAergic neuron                       NaN
# 9836            RSC-207         GABAergic            Sst Hpse Cbln4
# 9837            RSC-207         GABAergic           Sst Hpse Sema3c
# 9838            RSC-207         GABAergic          Sst Tac2 Tacstd2
# 9839            RSC-207     Glutamatergic  L5 IT VISp Hsd11b1 Endou
# 9840            RSC-207         GABAergic                     n_Sst
# 9841            RSC-207         GABAergic            Sst Hpse Cbln4
# 9842            RSC-207  GABAergic neuron                       NaN
#
#                      cluster_label marker_sum_norm_label  \
# 0                              n91              0.571161
# 1                              n91              0.797319
# 2                               n3              0.205138
# 3                               n6              0.598208
# 4                               n5              0.261427
# 5                 L4 IT VISp Rspo1              1.011053
# 6                              n59              0.543551
# 7                 Vip Lmo1 Fam159b              1.062120
# 8                             n100              0.788812
# 9                       Lamp5 Lsp1              0.974841
# 10                              n3              0.407652
# 11                             n59              0.584632
# 12                              n4              0.314863
# 13                        Sst Esm1              0.872312
# 14                              n3              0.267158
# 15                   Vip Lmo1 Myl1              0.966441
# 16                             n89              0.576443
# 17                              n3              0.426114
# 18                              n4              0.286005
# 19                             n28              0.330158
# 20                      Lamp5 Lsp1              0.793104
# 21                      Pvalb Tpbg              0.798853
# 22                             n59              0.421481
# 23                             n91              0.424297
# 24                             n59              0.377056
# 25                              n9              0.333327
# 26                             n60              1.212770
# 27                             n91              0.892597
# 28                             n28              0.785603
# 29                             n59              0.727140
# ...                            ...                   ...
# 9813          Inh L2-4 PVALB WFDC2              1.200423
# 9814           Inh L1-2 PAX6 CDH12              1.098992
# 9815  Inh L1-2 SST BAGE2 (ADARB2+)              0.894691
# 9816                          FAIL              0.283756
# 9817  Inh L1-2 GAD1 MC4R (ADARB2+)              0.966119
# 9818  Inh L1-2 GAD1 MC4R (ADARB2+)              1.122223
# 9819                           NaN                   NaN
# 9820     Inh L1 SST NMBR (ADARB2+)              0.902165
# 9821      L5 IT VISp Hsd11b1 Endou              0.915702
# 9822          Inh L1-2 VIP TSPAN12              0.970922
# 9823     Inh L1 SST NMBR (ADARB2+)              1.011454
# 9824                       PVALB|b              0.875524
# 9825                           n39              1.143928
# 9826                           n28              0.912406
# 9827       L6 IT VISp Penk Col27a1              0.991007
# 9828          Inh L2-4 PVALB WFDC2              1.076351
# 9829          L6 CT VISp Krt80 Sla              0.914958
# 9830                           n30              0.794211
# 9831                        ADARB2              0.456577
# 9832                    Inhibitory              0.363268
# 9833                        LHX6|c              1.138475
# 9834                         SST|g              0.788484
# 9835                       PVALB|b              0.754288
# 9836                Sst Hpse Cbln4              1.066398
# 9837               Sst Hpse Sema3c              0.877918
# 9838              Sst Tac2 Tacstd2              0.935307
# 9839      L5 IT VISp Hsd11b1 Endou              0.822263
# 9840                           n91              1.034984
# 9841                Sst Hpse Cbln4              0.975769
# 9842          Inh L2-4 PVALB WFDC2              1.192857
#
#      percent_cdna_longer_than_400bp res_index      roi  \
# 0                             0.314  0.714428    VISp5
# 1                             0.623  0.714428  VISp2-3
# 2                             0.295  0.000000    VISp5
# 3                             0.418  0.604422    VISp4
# 4                             0.609  0.542001    VISp5
# 5                             0.702  1.000000  VISp2-3
# 6                             0.442  0.434669    VISp4
# 7                             0.430  1.000000    VISp5
# 8                             0.433  0.860419    VISp5
# 9                             0.751  1.000000  VISp2-3
# 10                            0.486  0.000000    VISp4
# 11                            0.618  0.434669    VISp5
# 12                            0.334  0.291080  VISp2-3
# 13                            0.672  1.000000    VISp5
# 14                            0.479  0.000000    VISp4
# 15                            0.715  1.000000    VISp5
# 16                            0.319  0.580975    VISp5
# 17                            0.387  0.000000  VISp2-3
# 18                            0.436  0.291080   VISp6a
# 19                            0.274  0.791615    VISp5
# 20                            0.698  1.000000  VISp2-3
# 21                            0.745  1.000000    VISp4
# 22                            0.497  0.434669  VISp2-3
# 23                            0.501  0.714428   VISp6a
# 24                            0.430  0.434669    VISp4
# 25                            0.355  0.845780    VISp5
# 26                            0.534  0.548225    VISp5
# 27                            0.488  0.714428   VISp6b
# 28                            0.522  0.791615    VISp5
# 29                            0.665  0.434669    VISp4
# ...                             ...       ...      ...
# 9813                          0.606  1.000000   TCx_L3
# 9814                          0.380  1.000000   TCx_L1
# 9815                          0.590  1.000000   TCx_L1
# 9816                          0.257  0.000000   TCx_L1
# 9817                          0.399  1.000000   TCx_L1
# 9818                          0.577  1.000000   TCx_L1
# 9819                            NaN       NaN      NaN
# 9820                          0.397  1.000000   TCx_L1
# 9821                          0.572  1.000000    VISp4
# 9822                          0.524  1.000000   TCx_L1
# 9823                          0.510  1.000000   TCx_L1
# 9824                          0.656  0.855071   TCx_L5
# 9825                          0.650  0.862940  VISp2-3
# 9826                          0.574  0.791615   VISp6a
# 9827                          0.578  1.000000   VISp6a
# 9828                          0.645  1.000000   TCx_L3
# 9829                          0.625  1.000000   VISp6b
# 9830                          0.428  0.861701    VISp5
# 9831                          0.571  0.380325   TCx_L5
# 9832                          0.362  0.254718   TCx_L5
# 9833                          0.461  0.504463   TCx_L3
# 9834                          0.515  0.821872   TCx_L3
# 9835                          0.810  0.855071   TCx_L4
# 9836                          0.651  1.000000    VISp4
# 9837                          0.480  1.000000    VISp5
# 9838                          0.618  1.000000   VISp6a
# 9839                          0.622  1.000000    VISp4
# 9840                          0.446  0.714428   VISp6a
# 9841                          0.635  1.000000    VISp4
# 9842                          0.657  1.000000   TCx_L5
#
#               seurat_cluster_label    subclass_label
# 0                              NaN               Sst
# 1                              NaN               Sst
# 2                              NaN               L6b
# 3                              NaN                L4
# 4                              NaN             L6 CT
# 5                              NaN                L4
# 6                              NaN          Serpinf1
# 7                              NaN               Vip
# 8                              NaN               Sst
# 9                              NaN             Lamp5
# 10                             NaN               Vip
# 11                             NaN             Pvalb
# 12                             NaN               Sst
# 13                             NaN               Sst
# 14                             NaN               Sst
# 15                             NaN               Vip
# 16                             NaN               Sst
# 17                             NaN               Sst
# 18                             NaN             L6 CT
# 19                             NaN             L5 IT
# 20                             NaN             Lamp5
# 21                             NaN             Pvalb
# 22                             NaN             Lamp5
# 23                             NaN               Sst
# 24                             NaN             Lamp5
# 25                             NaN             L5 PT
# 26                             NaN               Vip
# 27                             NaN               Sst
# 28                             NaN             L5 IT
# 29                             NaN             Pvalb
# ...                            ...               ...
# 9813          Inh L2-4 PVALB WFDC2             PVALB
# 9814           Inh L1-2 PAX6 CDH12  LAMP5/PAX6/Other
# 9815         Inh L1-3 VIP ADAMTSL1  LAMP5/PAX6/Other
# 9816          Inh L2-4 PVALB WFDC2  LAMP5/PAX6/Other
# 9817  Inh L1-2 GAD1 MC4R (ADARB2+)  LAMP5/PAX6/Other
# 9818  Inh L1-2 GAD1 MC4R (ADARB2+)  LAMP5/PAX6/Other
# 9819                           NaN               NaN
# 9820     Inh L1 SST NMBR (ADARB2+)  LAMP5/PAX6/Other
# 9821                           NaN             L5 IT
# 9822          Inh L1-2 VIP TSPAN12               VIP
# 9823     Inh L1 SST NMBR (ADARB2+)  LAMP5/PAX6/Other
# 9824           Inh L4-5 PVALB MEPE             PVALB
# 9825                           NaN           L2/3 IT
# 9826                           NaN             L5 IT
# 9827                           NaN             L6 IT
# 9828          Inh L2-4 PVALB WFDC2             PVALB
# 9829                           NaN             L6 CT
# 9830                           NaN             L5 IT
# 9831           Exc L6 FEZF2 SCUBE1  LAMP5/PAX6/Other
# 9832            Inh L1-3 SST CALB1             PVALB
# 9833          Inh L2-4 PVALB WFDC2             PVALB
# 9834           Inh L3-5 SST ADGRG6               SST
# 9835          Inh L2-4 PVALB WFDC2             PVALB
# 9836                           NaN               Sst
# 9837                           NaN               Sst
# 9838                           NaN               Sst
# 9839                           NaN             L5 IT
# 9840                           NaN               Sst
# 9841                           NaN               Sst
# 9842          Inh L2-4 PVALB WFDC2             PVALB
#
# [9843 rows x 39 columns]

# %% [markdown]
# # Merge LIMS and Shiny dataframes, save to csv

# %%
ephys_shiny_df = pd.merge(left = lims_df, 
                    right = shiny_df, 
                    left_on = 'name', #ephys
                    right_on = 'cell_name', #shiny
                    how = 'left')
ephys_shiny_df[ephys_shiny_df['name'].str.contains('H19.06.356.21.06.04.01')]['project_code']
# Out:
# Series([], Name: project_code, dtype: object)

# %%
ephys_shiny_df.to_csv("MET_data_191101.csv")

# %%
ephys_shiny_df['subclass_label'].unique()
# Out:
# array(['Vip', 'Lamp5', 'Sst', 'L5 IT', 'Pvalb', 'Serpinf1', 'Sncg',
#        'L6 CT', 'L5 PT', nan, 'L6 IT', 'L2/3 IT', 'L4', 'Meis2', 'NP',
#        'L6b'], dtype=object)
